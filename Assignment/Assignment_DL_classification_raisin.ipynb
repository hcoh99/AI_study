# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

# %%
df = pd.read_excel('/Users/ohheungchan/workspace/AI_Study/Raisin_Dataset.xlsx')
df
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter    Class
# 0    0.758651   1184.040  Kecimen
# 1    0.684130   1121.786  Kecimen
# 2    0.637613   1208.575  Kecimen
# 3    0.699599    844.162  Kecimen
# 4    0.792772   1073.251  Kecimen
# ..        ...        ...      ...
# 895  0.668793   1129.072    Besni
# 896  0.636476   1214.252    Besni
# 897  0.741099   1292.828    Besni
# 898  0.658798   1258.548    Besni
# 899  0.632020   1272.862    Besni
#
# [900 rows x 8 columns]

# %%
y = df['Class']
y.value_counts()
# Out:
# Kecimen    450
# Besni      450
# Name: Class, dtype: int64

# %%
x = df.drop('Class' , axis=1)
x
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter
# 0    0.758651   1184.040
# 1    0.684130   1121.786
# 2    0.637613   1208.575
# 3    0.699599    844.162
# 4    0.792772   1073.251
# ..        ...        ...
# 895  0.668793   1129.072
# 896  0.636476   1214.252
# 897  0.741099   1292.828
# 898  0.658798   1258.548
# 899  0.632020   1272.862
#
# [900 rows x 7 columns]

# %% [markdown]
# # 원-핫 인코딩

# %%
Y = pd.get_dummies(y).values

# %%
Y
# Out:
# array([[0, 1],
#        [0, 1],
#        [0, 1],
#        ...,
#        [1, 0],
#        [1, 0],
#        [1, 0]], dtype=uint8)

# %%
X = x.values

# %%
X
# Out:
# array([[8.75240000e+04, 4.42246011e+02, 2.53291155e+02, ...,
#         9.05460000e+04, 7.58650579e-01, 1.18404000e+03],
#        [7.51660000e+04, 4.06690687e+02, 2.43032436e+02, ...,
#         7.87890000e+04, 6.84129570e-01, 1.12178600e+03],
#        [9.08560000e+04, 4.42267048e+02, 2.66328318e+02, ...,
#         9.37170000e+04, 6.37612812e-01, 1.20857500e+03],
#        ...,
#        [9.96570000e+04, 4.31706981e+02, 2.98837323e+02, ...,
#         1.06264000e+05, 7.41098519e-01, 1.29282800e+03],
#        [9.35230000e+04, 4.76344094e+02, 2.54176054e+02, ...,
#         9.76530000e+04, 6.58798253e-01, 1.25854800e+03],
#        [8.56090000e+04, 5.12081774e+02, 2.15271976e+02, ...,
#         8.91970000e+04, 6.32019963e-01, 1.27286200e+03]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(7,input_shape=(7,),activation='tanh'))
model.add(Dense(10,activation='tanh'))
model.add(Dense(15,activation='tanh'))
model.add(Dense(10,activation='tanh'))
model.add(Dense(2,activation='sigmoid'))

model.compile(Adam(lr=0.04),'binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_22 (Dense)            (None, 7)                 56
#
#  dense_23 (Dense)            (None, 10)                80
#
#  dense_24 (Dense)            (None, 15)                165
#
#  dense_25 (Dense)            (None, 10)                160
#
#  dense_26 (Dense)            (None, 2)                 22
#
# =================================================================
# Total params: 483
# Trainable params: 483
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=50, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7112 - accuracy: 0.5069 - val_loss: 0.7071 - val_accuracy: 0.4611
# Epoch 2/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7061 - accuracy: 0.4958 - val_loss: 0.6947 - val_accuracy: 0.5389
# Epoch 3/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7017 - accuracy: 0.4597 - val_loss: 0.6943 - val_accuracy: 0.5389
# Epoch 4/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6989 - accuracy: 0.5208 - val_loss: 0.7058 - val_accuracy: 0.4611
# Epoch 5/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7011 - accuracy: 0.5292 - val_loss: 0.6902 - val_accuracy: 0.5389
# Epoch 6/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6984 - accuracy: 0.5264 - val_loss: 0.6970 - val_accuracy: 0.4611
# Epoch 7/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6970 - accuracy: 0.5014 - val_loss: 0.6958 - val_accuracy: 0.4611
# Epoch 8/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6963 - accuracy: 0.5347 - val_loss: 0.6914 - val_accuracy: 0.5389
# Epoch 9/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6997 - accuracy: 0.4597 - val_loss: 0.7017 - val_accuracy: 0.4611
# Epoch 10/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6960 - accuracy: 0.5319 - val_loss: 0.6902 - val_accuracy: 0.5389
# Epoch 11/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6978 - accuracy: 0.4931 - val_loss: 0.6913 - val_accuracy: 0.5389
# Epoch 12/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7031 - accuracy: 0.4736 - val_loss: 0.6903 - val_accuracy: 0.5389
# Epoch 13/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6936 - accuracy: 0.5125 - val_loss: 0.6904 - val_accuracy: 0.5389
# Epoch 14/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7046 - accuracy: 0.5042 - val_loss: 0.6907 - val_accuracy: 0.5389
# Epoch 15/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6980 - accuracy: 0.4958 - val_loss: 0.6916 - val_accuracy: 0.5389
# Epoch 16/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7074 - accuracy: 0.4847 - val_loss: 0.7684 - val_accuracy: 0.4611
# Epoch 17/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7003 - accuracy: 0.5208 - val_loss: 0.7124 - val_accuracy: 0.4611
# Epoch 18/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7036 - accuracy: 0.5125 - val_loss: 0.7305 - val_accuracy: 0.4611
# Epoch 19/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6983 - accuracy: 0.4903 - val_loss: 0.6903 - val_accuracy: 0.5389
# Epoch 20/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6969 - accuracy: 0.5125 - val_loss: 0.7001 - val_accuracy: 0.4611
# Epoch 21/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7008 - accuracy: 0.4875 - val_loss: 0.6904 - val_accuracy: 0.5389
# Epoch 22/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6990 - accuracy: 0.4819 - val_loss: 0.6952 - val_accuracy: 0.4611
# Epoch 23/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6968 - accuracy: 0.5042 - val_loss: 0.6944 - val_accuracy: 0.4611
# Epoch 24/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7017 - accuracy: 0.5042 - val_loss: 0.6985 - val_accuracy: 0.4611
# Epoch 25/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6993 - accuracy: 0.4931 - val_loss: 0.7225 - val_accuracy: 0.4611
# Epoch 26/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7150 - accuracy: 0.4958 - val_loss: 0.6986 - val_accuracy: 0.4611
# Epoch 27/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7065 - accuracy: 0.4903 - val_loss: 0.6902 - val_accuracy: 0.5389
# Epoch 28/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7077 - accuracy: 0.4903 - val_loss: 0.6982 - val_accuracy: 0.4611
# Epoch 29/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6994 - accuracy: 0.4903 - val_loss: 0.6914 - val_accuracy: 0.5389
# Epoch 30/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6988 - accuracy: 0.5181 - val_loss: 0.6908 - val_accuracy: 0.5389
# Epoch 31/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7003 - accuracy: 0.5069 - val_loss: 0.6904 - val_accuracy: 0.5389
# Epoch 32/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6995 - accuracy: 0.4958 - val_loss: 0.7067 - val_accuracy: 0.4611
# Epoch 33/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6964 - accuracy: 0.5014 - val_loss: 0.7033 - val_accuracy: 0.4611
# Epoch 34/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6959 - accuracy: 0.4958 - val_loss: 0.6906 - val_accuracy: 0.5389
# Epoch 35/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6979 - accuracy: 0.5069 - val_loss: 0.6932 - val_accuracy: 0.5389
# Epoch 36/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6996 - accuracy: 0.4903 - val_loss: 0.6976 - val_accuracy: 0.4611
# Epoch 37/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6956 - accuracy: 0.5014 - val_loss: 0.7020 - val_accuracy: 0.4611
# Epoch 38/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6965 - accuracy: 0.4931 - val_loss: 0.6918 - val_accuracy: 0.5389
# Epoch 39/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6963 - accuracy: 0.4875 - val_loss: 0.7082 - val_accuracy: 0.4611
# Epoch 40/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6949 - accuracy: 0.4847 - val_loss: 0.6914 - val_accuracy: 0.5389
# Epoch 41/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7022 - accuracy: 0.4819 - val_loss: 0.6944 - val_accuracy: 0.5389
# Epoch 42/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7081 - accuracy: 0.4903 - val_loss: 0.7005 - val_accuracy: 0.4611
# Epoch 43/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7008 - accuracy: 0.4597 - val_loss: 0.6956 - val_accuracy: 0.4611
# Epoch 44/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6996 - accuracy: 0.4736 - val_loss: 0.7120 - val_accuracy: 0.4611
# Epoch 45/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7041 - accuracy: 0.4931 - val_loss: 0.7248 - val_accuracy: 0.4611
# Epoch 46/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7042 - accuracy: 0.4931 - val_loss: 0.7023 - val_accuracy: 0.5389
# Epoch 47/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7089 - accuracy: 0.4931 - val_loss: 0.6986 - val_accuracy: 0.4611
# Epoch 48/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6960 - accuracy: 0.5181 - val_loss: 0.6907 - val_accuracy: 0.5389
# Epoch 49/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7045 - accuracy: 0.4875 - val_loss: 0.6930 - val_accuracy: 0.5389
# Epoch 50/50
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6981 - accuracy: 0.4792 - val_loss: 0.7175 - val_accuracy: 0.4611
# 6/6 [==============================] - 0s 532us/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        97
#            1       0.46      1.00      0.63        83
#
#     accuracy                           0.46       180
#    macro avg       0.23      0.50      0.32       180
# weighted avg       0.21      0.46      0.29       180
#
# [[ 0 97]
#  [ 0 83]]
# /Users/ohheungchan/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ohheungchan/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ohheungchan/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

from tensorflow.keras.utils import to_categorical
import tensorflow.keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional
from tensorflow.keras.layers import Input, TimeDistributed, Conv1D, MaxPooling1D, BatchNormalization, Activation, UpSampling1D
from tensorflow.keras.layers import add, multiply, GlobalAveragePooling1D
from keras import  backend as K

# %%
from typing import Any, Dict, List, Tuple
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns


def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values



# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y


# load the dataset, returns train and test X and y elements
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '/Users/ohheungchan/workspace/AI_Study/Paperwork/human+activity+recognition+using+smartphones/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '/Users/ohheungchan/workspace/AI_Study/Paperwork/human+activity+recognition+using+smartphones/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
# Out:
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)

# %%
from sklearn.preprocessing import StandardScaler

def scale_data(trainX, testX):
 # remove overlap
 cut = int(trainX.shape[1] / 2)
 longX = trainX[:, -cut:, :]
 # flatten windows
 longX = longX.reshape((longX.shape[0] * longX.shape[1], longX.shape[2]))
 # flatten train and test
 flatTrainX = trainX.reshape((trainX.shape[0] * trainX.shape[1], trainX.shape[2]))
 flatTestX = testX.reshape((testX.shape[0] * testX.shape[1], testX.shape[2]))

 s = StandardScaler()
 # fit on training data
 s.fit(longX)
 # apply to training and test data
 longX = s.transform(longX)
 flatTrainX = s.transform(flatTrainX)
 flatTestX = s.transform(flatTestX)
 # reshape
 flatTrainX = flatTrainX.reshape((trainX.shape))
 flatTestX = flatTestX.reshape((testX.shape))
 return flatTrainX, flatTestX

# %%
trainX, testX = scale_data(trainX, testX)

# %%
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)
# Out:
# X train shape:  (7352, 128, 9)
# Y train shape:  (7352, 1)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 9)
# Y test shape:  (2947, 1)
# Y test One hot shape:  (2947, 6)

# %%
from sklearn.model_selection import train_test_split
X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX, trainy_one_hot, trainy,test_size=0.3,random_state=100)

# %%
def class_breakdown(data):
    # convert the numpy array into a dataframe
    df = pd.DataFrame(data)
    # group data by the class value and calculate the number of rows
    counts = df.groupby(0).size()
    # retrieve raw rows
    counts = counts.values
    # summarize
    for i in range(len(counts)):
        percent = counts[i] / len(df) * 100
        print('Class=%d, total=%d, percentage=%.3f' % (i+1, counts[i], percent))

# %%
class_breakdown(y_train)
# Out:
# Class=1, total=870, percentage=16.906
# Class=2, total=754, percentage=14.652
# Class=3, total=670, percentage=13.020
# Class=4, total=900, percentage=17.489
# Class=5, total=964, percentage=18.733
# Class=6, total=988, percentage=19.199

# %%
class_breakdown(y_val)
# Out:
# Class=1, total=356, percentage=16.138
# Class=2, total=319, percentage=14.461
# Class=3, total=316, percentage=14.325
# Class=4, total=386, percentage=17.498
# Class=5, total=410, percentage=18.586
# Class=6, total=419, percentage=18.994

# %%
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy_one_hot.shape[1]
n_timesteps, n_features, n_outputs
# Out:
# (128, 9, 6)

# %%
def conv_block(in_x, nb_filter, kernel_size):

    x = Conv1D(nb_filter, kernel_size, padding='same')(in_x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def convolutional_block(in_x, nb_filters, stride):

    F1, F2, F3 = nb_filters

    x = in_x

    x = Conv1D(F1, 3, strides=stride,  padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv1D(F2, 3, strides=1, padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv1D(F3, 1, strides=1, padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)

    x1 = Conv1D(F3, 1, strides=stride, padding='same', kernel_initializer="he_normal")(in_x)
    x1 = BatchNormalization()(x1)

    x = add([x, x1])
    x = Activation('relu')(x)

    return x

# %%
def attention_branch(in_x, nb_filter, kernel_size):

    x1 = conv_block(in_x, nb_filter, kernel_size)

    x = MaxPooling1D(2)(x1)
    x = conv_block(x, nb_filter, kernel_size)
    x = UpSampling1D(size = 2)(x)

    x2 = conv_block(x, nb_filter, kernel_size)

    if(K.int_shape(x1)!=K.int_shape(x2)):
        x2 = ZeroPadding1D(1)(x2)
        x2 = Cropping1D((1,0))(x2)

    x = add([x1, x2])

    x = conv_block(x, nb_filter, kernel_size)

    x = Conv1D(nb_filter, 1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('sigmoid')(x)

    return x

# %%
#Residual-Based Temporal Attention Block

def RTA_block(in_x, nb_filter, kernel_size):

    x1 = conv_block(in_x, nb_filter, kernel_size)
    x2 = conv_block(x1, nb_filter, kernel_size)

    attention_map = attention_branch(x1, nb_filter, kernel_size)

    x = multiply([x2, attention_map])
    x = add([x, x1])

    out = conv_block(x, nb_filter, kernel_size)

    return out

# %%
def RTA_CNN():

    inputs = Input(shape=(n_timesteps,n_features))

    x = RTA_block(inputs, 16, 32)
    x = MaxPooling1D(4)(x)

    x = RTA_block(x, 32, 16)
    x = MaxPooling1D(4)(x)

    x = RTA_block(x, 64, 9)
    x = MaxPooling1D(2)(x)
    x = RTA_block(x, 64, 9)
    x = MaxPooling1D(2)(x)
    x = Dropout(0.6)(x)

    x = RTA_block(x, 128, 3)
    x = MaxPooling1D(2)(x)
    x = RTA_block(x, 128, 3)
    x = MaxPooling1D(2)(x)
    x = Dropout(0.6)(x)

    x = Flatten()(x)
    x = Dropout(0.7)(x)
    x = Dense(100,  activation='relu')(x)
    x = Dropout(0.7)(x)
    x = Dense(n_outputs,  activation='softmax')(x)

    model = Model(inputs, x)

    return model

# %%
def se_block(in_x, nb_filter):
        squeeze = GlobalAveragePooling1D()(in_x)
        excitation = Dense(units=nb_filter // 2)(squeeze)
        excitation = Activation('relu')(excitation)
        excitation = Dense(units=nb_filter)(excitation)
        excitation = Activation('sigmoid')(excitation)
        excitation = Reshape((1,nb_filter))(excitation)
        scale = multiply([in_x,excitation])
        out = add([in_x, scale])

        return out

# %%
def SENET():

    inputs = Input(shape=(n_timesteps,n_features))

    x = Conv1D(16, 32, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 16)
    x = MaxPooling1D(4)(x)

    x = Conv1D(32, 16, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 32)
    x = MaxPooling1D(4)(x)

    x = Conv1D(64, 9, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 64)
    x = MaxPooling1D(2)(x)

    x = Conv1D(64, 9, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 64)
    x = MaxPooling1D(2)(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 128)
    x = MaxPooling1D(2)(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 128)
    x = MaxPooling1D(1)(x)

    x = Flatten()(x)
    x = Dense(300,  activation='relu')(x)
    x = Dense(n_outputs,  activation='softmax')(x)

    model = Model(inputs, x)

    return model

# %%
def RESNET50():

    inputs = Input(shape=(n_timesteps,n_features))

    filter_num = 64

    x = Conv1D(filter_num, 3, strides=2, kernel_initializer="he_normal")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPooling1D(3, stride=2)(x)

    x = convolutional_block(x, [filter_num, filter_num, filter_num * 4], 4)
    x = identity_block(x, [filter_num, filter_num, filter_num * 4])
    x = identity_block(x, [filter_num, filter_num, filter_num * 4])

    x = convolutional_block(x, [filter_num * 2, filter_num * 2, filter_num * 8], 4)
    x = identity_block(x, [filter_num * 2, filter_num * 2, filter_num * 8])
    x = identity_block(x, [filter_num * 2, filter_num * 2, filter_num * 8])
    x = identity_block(x, [filter_num * 2, filter_num * 2, filter_num * 8])

    x = convolutional_block(x, [filter_num * 4, filter_num * 4, filter_num * 16], 2)
    x = identity_block(x, [filter_num * 4, filter_num * 4, filter_num * 16])
    x = identity_block(x, [filter_num * 4, filter_num * 4, filter_num * 16])
    x = identity_block(x, [filter_num * 4, filter_num * 4, filter_num * 16])
    x = identity_block(x, [filter_num * 4, filter_num * 4, filter_num * 16])
    x = identity_block(x, [filter_num * 4, filter_num * 4, filter_num * 16])

    x = convolutional_block(x, [filter_num * 8, filter_num * 8, filter_num * 32], 2)
    x = identity_block(x, [filter_num * 8, filter_num * 8, filter_num * 32])
    x = identity_block(x, [filter_num * 8, filter_num * 8, filter_num * 32])

    x = GlobalAveragePooling1D()(x)
    x = Dense(500, activation="relu", kernel_initializer="he_normal")(x)
    x = Dense(n_outputs, activation="softmax")(x)

    model = Model(inputs, x)

    return model

# %%
import math

def en_loss(y_true, y_pred):

    epsilon = 1.e-7
    gamma = float(0.3)

    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
    pos_pred = tf.pow(-tf.math.log(y_pred),gamma)
    nag_pred = tf.pow(-tf.math.log(1-y_pred),gamma)
    y_t = tf.multiply(y_true, pos_pred) + tf.multiply(1-y_true, nag_pred)
    en_loss = tf.reduce_mean(y_t)
    return en_loss

# %%
from keras.models import Model
model = SENET()
model.summary()
model.compile(optimizer = 'adam', loss=en_loss, metrics = ["accuracy"])
# Out:
# Metal device set to: Apple M2 Pro
# 2024-03-19 22:10:01.613163: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-03-19 22:10:01.613668: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 9)]     0           []
#
#  conv1d (Conv1D)                (None, 128, 16)      4624        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 128, 16)     64          ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 128, 16)      0           ['batch_normalization[0][0]']
#
#  global_average_pooling1d (Glob  (None, 16)          0           ['activation[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 8)            136         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  activation_1 (Activation)      (None, 8)            0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 16)           144         ['activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 16)           0           ['dense_1[0][0]']
#
#  reshape (Reshape)              (None, 1, 16)        0           ['activation_2[0][0]']
#
#  multiply (Multiply)            (None, 128, 16)      0           ['activation[0][0]',
#                                                                   'reshape[0][0]']
#
#  add (Add)                      (None, 128, 16)      0           ['activation[0][0]',
#                                                                   'multiply[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 32, 16)       0           ['add[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 32, 32)       8224        ['max_pooling1d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32)      128         ['conv1d_1[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32)       0           ['batch_normalization_1[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 32)          0           ['activation_3[0][0]']
#  obalAveragePooling1D)
#
#  dense_2 (Dense)                (None, 16)           528         ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  activation_4 (Activation)      (None, 16)           0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 32)           544         ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 32)           0           ['dense_3[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 32)        0           ['activation_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 32, 32)       0           ['activation_3[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  add_1 (Add)                    (None, 32, 32)       0           ['activation_3[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 8, 32)       0           ['add_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 8, 64)        18496       ['max_pooling1d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 64)       256         ['conv1d_2[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 8, 64)        0           ['batch_normalization_2[0][0]']
#
#  global_average_pooling1d_2 (Gl  (None, 64)          0           ['activation_6[0][0]']
#  obalAveragePooling1D)
#
#  dense_4 (Dense)                (None, 32)           2080        ['global_average_pooling1d_2[0][0
#                                                                  ]']
#
#  activation_7 (Activation)      (None, 32)           0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 64)           2112        ['activation_7[0][0]']
#
#  activation_8 (Activation)      (None, 64)           0           ['dense_5[0][0]']
#
#  reshape_2 (Reshape)            (None, 1, 64)        0           ['activation_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 8, 64)        0           ['activation_6[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  add_2 (Add)                    (None, 8, 64)        0           ['activation_6[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 4, 64)       0           ['add_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 4, 64)        36928       ['max_pooling1d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 4, 64)       256         ['conv1d_3[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 4, 64)        0           ['batch_normalization_3[0][0]']
#
#  global_average_pooling1d_3 (Gl  (None, 64)          0           ['activation_9[0][0]']
#  obalAveragePooling1D)
#
#  dense_6 (Dense)                (None, 32)           2080        ['global_average_pooling1d_3[0][0
#                                                                  ]']
#
#  activation_10 (Activation)     (None, 32)           0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 64)           2112        ['activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 64)           0           ['dense_7[0][0]']
#
#  reshape_3 (Reshape)            (None, 1, 64)        0           ['activation_11[0][0]']
#
#  multiply_3 (Multiply)          (None, 4, 64)        0           ['activation_9[0][0]',
#                                                                   'reshape_3[0][0]']
#
#  add_3 (Add)                    (None, 4, 64)        0           ['activation_9[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 2, 64)       0           ['add_3[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 2, 128)       24704       ['max_pooling1d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 2, 128)      512         ['conv1d_4[0][0]']
#  rmalization)
#
#  activation_12 (Activation)     (None, 2, 128)       0           ['batch_normalization_4[0][0]']
#
#  global_average_pooling1d_4 (Gl  (None, 128)         0           ['activation_12[0][0]']
#  obalAveragePooling1D)
#
#  dense_8 (Dense)                (None, 64)           8256        ['global_average_pooling1d_4[0][0
#                                                                  ]']
#
#  activation_13 (Activation)     (None, 64)           0           ['dense_8[0][0]']
#
#  dense_9 (Dense)                (None, 128)          8320        ['activation_13[0][0]']
#
#  activation_14 (Activation)     (None, 128)          0           ['dense_9[0][0]']
#
#  reshape_4 (Reshape)            (None, 1, 128)       0           ['activation_14[0][0]']
#
#  multiply_4 (Multiply)          (None, 2, 128)       0           ['activation_12[0][0]',
#                                                                   'reshape_4[0][0]']
#
#  add_4 (Add)                    (None, 2, 128)       0           ['activation_12[0][0]',
#                                                                   'multiply_4[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 1, 128)      0           ['add_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 1, 128)       49280       ['max_pooling1d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 1, 128)      512         ['conv1d_5[0][0]']
#  rmalization)
#
#  activation_15 (Activation)     (None, 1, 128)       0           ['batch_normalization_5[0][0]']
#
#  global_average_pooling1d_5 (Gl  (None, 128)         0           ['activation_15[0][0]']
#  obalAveragePooling1D)
#
#  dense_10 (Dense)               (None, 64)           8256        ['global_average_pooling1d_5[0][0
#                                                                  ]']
#
#  activation_16 (Activation)     (None, 64)           0           ['dense_10[0][0]']
#
#  dense_11 (Dense)               (None, 128)          8320        ['activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 128)          0           ['dense_11[0][0]']
#
#  reshape_5 (Reshape)            (None, 1, 128)       0           ['activation_17[0][0]']
#
#  multiply_5 (Multiply)          (None, 1, 128)       0           ['activation_15[0][0]',
#                                                                   'reshape_5[0][0]']
#
#  add_5 (Add)                    (None, 1, 128)       0           ['activation_15[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 1, 128)      0           ['add_5[0][0]']
#
#  flatten (Flatten)              (None, 128)          0           ['max_pooling1d_5[0][0]']
#
#  dense_12 (Dense)               (None, 300)          38700       ['flatten[0][0]']
#
#  dense_13 (Dense)               (None, 6)            1806        ['dense_12[0][0]']
#
# ==================================================================================================
# Total params: 227,378
# Trainable params: 226,514
# Non-trainable params: 864
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
import math
import time

start = time.time()
model_history=model.fit(X_train, y_train_one_hot, epochs=100, batch_size=32,validation_data=(X_val,y_val_one_hot))


end = time.time()
print(f"{end - start:.5f} sec")
# Out:
# Epoch 1/100
# 2024-03-19 22:10:26.882761: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-03-19 22:10:28.327360: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 161/161 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.8391
# 2024-03-19 22:10:40.481592: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 161/161 [==============================] - 15s 55ms/step - loss: 0.1294 - accuracy: 0.8391 - val_loss: 0.1587 - val_accuracy: 0.7860
# Epoch 2/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0587 - accuracy: 0.9281 - val_loss: 0.0491 - val_accuracy: 0.9424
# Epoch 3/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0523 - accuracy: 0.9386 - val_loss: 0.0470 - val_accuracy: 0.9451
# Epoch 4/100
# 161/161 [==============================] - 4s 28ms/step - loss: 0.0544 - accuracy: 0.9363 - val_loss: 0.0660 - val_accuracy: 0.9207
# Epoch 5/100
# 161/161 [==============================] - 4s 28ms/step - loss: 0.0543 - accuracy: 0.9353 - val_loss: 0.0564 - val_accuracy: 0.9338
# Epoch 6/100
# 161/161 [==============================] - 5s 28ms/step - loss: 0.0499 - accuracy: 0.9401 - val_loss: 0.0395 - val_accuracy: 0.9569
# Epoch 7/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0493 - accuracy: 0.9425 - val_loss: 0.0430 - val_accuracy: 0.9515
# Epoch 8/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0479 - accuracy: 0.9442 - val_loss: 0.0432 - val_accuracy: 0.9529
# Epoch 9/100
# 161/161 [==============================] - 4s 28ms/step - loss: 0.0460 - accuracy: 0.9471 - val_loss: 0.0434 - val_accuracy: 0.9497
# Epoch 10/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0547 - accuracy: 0.9351 - val_loss: 0.0507 - val_accuracy: 0.9388
# Epoch 11/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0480 - accuracy: 0.9435 - val_loss: 0.0393 - val_accuracy: 0.9583
# Epoch 12/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0501 - accuracy: 0.9413 - val_loss: 0.0446 - val_accuracy: 0.9492
# Epoch 13/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0495 - accuracy: 0.9421 - val_loss: 0.0410 - val_accuracy: 0.9547
# Epoch 14/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0492 - accuracy: 0.9421 - val_loss: 0.0432 - val_accuracy: 0.9479
# Epoch 15/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0486 - accuracy: 0.9438 - val_loss: 0.0395 - val_accuracy: 0.9560
# Epoch 16/100
# 161/161 [==============================] - 4s 28ms/step - loss: 0.0477 - accuracy: 0.9442 - val_loss: 0.0415 - val_accuracy: 0.9515
# Epoch 17/100
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0434 - accuracy: 0.9508 - val_loss: 0.0373 - val_accuracy: 0.9601
# Epoch 18/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0440 - accuracy: 0.9503 - val_loss: 0.0396 - val_accuracy: 0.9569
# Epoch 19/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0444 - accuracy: 0.9491 - val_loss: 0.0369 - val_accuracy: 0.9606
# Epoch 20/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0476 - accuracy: 0.9440 - val_loss: 0.0390 - val_accuracy: 0.9578
# Epoch 21/100
# 161/161 [==============================] - 5s 28ms/step - loss: 0.0467 - accuracy: 0.9458 - val_loss: 0.0405 - val_accuracy: 0.9547
# Epoch 22/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0421 - accuracy: 0.9522 - val_loss: 0.0377 - val_accuracy: 0.9592
# Epoch 23/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0508 - accuracy: 0.9394 - val_loss: 0.0404 - val_accuracy: 0.9547
# Epoch 24/100
# 161/161 [==============================] - 4s 28ms/step - loss: 0.0488 - accuracy: 0.9425 - val_loss: 0.0485 - val_accuracy: 0.9429
# Epoch 25/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0460 - accuracy: 0.9471 - val_loss: 0.0444 - val_accuracy: 0.9501
# Epoch 26/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0438 - accuracy: 0.9495 - val_loss: 0.0384 - val_accuracy: 0.9592
# Epoch 27/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0430 - accuracy: 0.9510 - val_loss: 0.0376 - val_accuracy: 0.9592
# Epoch 28/100
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0442 - accuracy: 0.9485 - val_loss: 0.0389 - val_accuracy: 0.9583
# Epoch 29/100
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0484 - accuracy: 0.9436 - val_loss: 0.0391 - val_accuracy: 0.9560
# Epoch 30/100
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0412 - accuracy: 0.9539 - val_loss: 0.0368 - val_accuracy: 0.9601
# Epoch 31/100
# 161/161 [==============================] - 4s 22ms/step - loss: 0.0438 - accuracy: 0.9473 - val_loss: 0.0373 - val_accuracy: 0.9610
# Epoch 32/100
# 161/161 [==============================] - 4s 23ms/step - loss: 0.0429 - accuracy: 0.9506 - val_loss: 0.0404 - val_accuracy: 0.9551
# Epoch 33/100
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0440 - accuracy: 0.9485 - val_loss: 0.0369 - val_accuracy: 0.9597
# Epoch 34/100
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0432 - accuracy: 0.9501 - val_loss: 0.0390 - val_accuracy: 0.9551
# Epoch 35/100
# 161/161 [==============================] - 4s 23ms/step - loss: 0.0442 - accuracy: 0.9481 - val_loss: 0.0392 - val_accuracy: 0.9583
# Epoch 36/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0426 - accuracy: 0.9524 - val_loss: 0.0380 - val_accuracy: 0.9587
# Epoch 37/100
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0403 - accuracy: 0.9539 - val_loss: 0.0385 - val_accuracy: 0.9597
# Epoch 38/100
# 161/161 [==============================] - 4s 28ms/step - loss: 0.0406 - accuracy: 0.9545 - val_loss: 0.0411 - val_accuracy: 0.9547
# Epoch 39/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0439 - accuracy: 0.9497 - val_loss: 0.0377 - val_accuracy: 0.9587
# Epoch 40/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0434 - accuracy: 0.9491 - val_loss: 0.0388 - val_accuracy: 0.9574
# Epoch 41/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0405 - accuracy: 0.9543 - val_loss: 0.0465 - val_accuracy: 0.9461
# Epoch 42/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0417 - accuracy: 0.9530 - val_loss: 0.0498 - val_accuracy: 0.9420
# Epoch 43/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0412 - accuracy: 0.9541 - val_loss: 0.0391 - val_accuracy: 0.9578
# Epoch 44/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0441 - accuracy: 0.9483 - val_loss: 0.0556 - val_accuracy: 0.9320
# Epoch 45/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0419 - accuracy: 0.9520 - val_loss: 0.0389 - val_accuracy: 0.9565
# Epoch 46/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0401 - accuracy: 0.9551 - val_loss: 0.0395 - val_accuracy: 0.9560
# Epoch 47/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0410 - accuracy: 0.9526 - val_loss: 0.0618 - val_accuracy: 0.9288
# Epoch 48/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0447 - accuracy: 0.9497 - val_loss: 0.0373 - val_accuracy: 0.9574
# Epoch 49/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0401 - accuracy: 0.9543 - val_loss: 0.0361 - val_accuracy: 0.9610
# Epoch 50/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0397 - accuracy: 0.9545 - val_loss: 0.0361 - val_accuracy: 0.9619
# Epoch 51/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0413 - accuracy: 0.9532 - val_loss: 0.0381 - val_accuracy: 0.9592
# Epoch 52/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0394 - accuracy: 0.9559 - val_loss: 0.0378 - val_accuracy: 0.9587
# Epoch 53/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0427 - accuracy: 0.9518 - val_loss: 0.0372 - val_accuracy: 0.9592
# Epoch 54/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0395 - accuracy: 0.9553 - val_loss: 0.0385 - val_accuracy: 0.9574
# Epoch 55/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0378 - accuracy: 0.9578 - val_loss: 0.0360 - val_accuracy: 0.9610
# Epoch 56/100
# 161/161 [==============================] - 5s 31ms/step - loss: 0.0410 - accuracy: 0.9534 - val_loss: 0.0375 - val_accuracy: 0.9569
# Epoch 57/100
# 161/161 [==============================] - 4s 28ms/step - loss: 0.0365 - accuracy: 0.9607 - val_loss: 0.0377 - val_accuracy: 0.9597
# Epoch 58/100
# 161/161 [==============================] - 5s 29ms/step - loss: 0.0381 - accuracy: 0.9582 - val_loss: 0.0352 - val_accuracy: 0.9615
# Epoch 59/100
# 161/161 [==============================] - 5s 29ms/step - loss: 0.0380 - accuracy: 0.9576 - val_loss: 0.0370 - val_accuracy: 0.9606
# Epoch 60/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0368 - accuracy: 0.9596 - val_loss: 0.0357 - val_accuracy: 0.9610
# Epoch 61/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0397 - accuracy: 0.9549 - val_loss: 0.0382 - val_accuracy: 0.9583
# Epoch 62/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0381 - accuracy: 0.9576 - val_loss: 0.0359 - val_accuracy: 0.9610
# Epoch 63/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0457 - accuracy: 0.9468 - val_loss: 0.0373 - val_accuracy: 0.9592
# Epoch 64/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0405 - accuracy: 0.9545 - val_loss: 0.0362 - val_accuracy: 0.9597
# Epoch 65/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0400 - accuracy: 0.9565 - val_loss: 0.0364 - val_accuracy: 0.9606
# Epoch 66/100
# 161/161 [==============================] - 4s 28ms/step - loss: 0.0393 - accuracy: 0.9561 - val_loss: 0.0364 - val_accuracy: 0.9597
# Epoch 67/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0354 - accuracy: 0.9621 - val_loss: 0.0356 - val_accuracy: 0.9615
# Epoch 68/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0368 - accuracy: 0.9604 - val_loss: 0.0366 - val_accuracy: 0.9606
# Epoch 69/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0409 - accuracy: 0.9547 - val_loss: 0.0366 - val_accuracy: 0.9606
# Epoch 70/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0390 - accuracy: 0.9565 - val_loss: 0.0368 - val_accuracy: 0.9587
# Epoch 71/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0384 - accuracy: 0.9578 - val_loss: 0.0367 - val_accuracy: 0.9597
# Epoch 72/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0383 - accuracy: 0.9590 - val_loss: 0.0384 - val_accuracy: 0.9569
# Epoch 73/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0372 - accuracy: 0.9594 - val_loss: 0.0438 - val_accuracy: 0.9510
# Epoch 74/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0377 - accuracy: 0.9584 - val_loss: 0.0355 - val_accuracy: 0.9610
# Epoch 75/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0349 - accuracy: 0.9623 - val_loss: 0.0361 - val_accuracy: 0.9592
# Epoch 76/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0356 - accuracy: 0.9613 - val_loss: 0.0353 - val_accuracy: 0.9624
# Epoch 77/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0346 - accuracy: 0.9629 - val_loss: 0.0346 - val_accuracy: 0.9619
# Epoch 78/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0363 - accuracy: 0.9602 - val_loss: 0.0385 - val_accuracy: 0.9569
# Epoch 79/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0331 - accuracy: 0.9658 - val_loss: 0.0345 - val_accuracy: 0.9651
# Epoch 80/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0334 - accuracy: 0.9639 - val_loss: 0.0338 - val_accuracy: 0.9642
# Epoch 81/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0351 - accuracy: 0.9619 - val_loss: 0.0341 - val_accuracy: 0.9646
# Epoch 82/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0381 - accuracy: 0.9565 - val_loss: 0.0337 - val_accuracy: 0.9637
# Epoch 83/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0334 - accuracy: 0.9646 - val_loss: 0.0354 - val_accuracy: 0.9619
# Epoch 84/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0339 - accuracy: 0.9644 - val_loss: 0.0345 - val_accuracy: 0.9637
# Epoch 85/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0339 - accuracy: 0.9644 - val_loss: 0.0369 - val_accuracy: 0.9592
# Epoch 86/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0338 - accuracy: 0.9646 - val_loss: 0.0364 - val_accuracy: 0.9610
# Epoch 87/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0356 - accuracy: 0.9617 - val_loss: 0.0335 - val_accuracy: 0.9655
# Epoch 88/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0338 - accuracy: 0.9637 - val_loss: 0.0368 - val_accuracy: 0.9610
# Epoch 89/100
# 161/161 [==============================] - 4s 27ms/step - loss: 0.0346 - accuracy: 0.9635 - val_loss: 0.0347 - val_accuracy: 0.9633
# Epoch 90/100
# 161/161 [==============================] - 4s 26ms/step - loss: 0.0338 - accuracy: 0.9640 - val_loss: 0.0337 - val_accuracy: 0.9642
# Epoch 91/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0331 - accuracy: 0.9660 - val_loss: 0.0339 - val_accuracy: 0.9637
# Epoch 92/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0332 - accuracy: 0.9646 - val_loss: 0.0345 - val_accuracy: 0.9615
# Epoch 93/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0331 - accuracy: 0.9656 - val_loss: 0.0368 - val_accuracy: 0.9592
# Epoch 94/100
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0311 - accuracy: 0.9681 - val_loss: 0.0330 - val_accuracy: 0.9665
# Epoch 95/100
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0317 - accuracy: 0.9674 - val_loss: 0.0322 - val_accuracy: 0.9669
# Epoch 96/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0326 - accuracy: 0.9662 - val_loss: 0.0332 - val_accuracy: 0.9646
# Epoch 97/100
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0315 - accuracy: 0.9675 - val_loss: 0.0312 - val_accuracy: 0.9674
# Epoch 98/100
# 161/161 [==============================] - 4s 24ms/step - loss: 0.0312 - accuracy: 0.9685 - val_loss: 0.0327 - val_accuracy: 0.9660
# Epoch 99/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0330 - accuracy: 0.9664 - val_loss: 0.0375 - val_accuracy: 0.9583
# Epoch 100/100
# 161/161 [==============================] - 4s 25ms/step - loss: 0.0329 - accuracy: 0.9650 - val_loss: 0.0349 - val_accuracy: 0.9633
# 427.08556 sec

# %%
loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

predy = model.predict(testX)
predy = np.argmax(predy, axis=1)

cm= confusion_matrix(testy,predy)
print(cm)
print(accuracy_score(testy,predy))
print(classification_report(testy,predy))
sns.heatmap(cm, annot=True, fmt = '.2f')
# Out:
# 93/93 [==============================] - 0s 4ms/step
# [[478   3  14   0   1   0]
#  [  0 448  23   0   0   0]
#  [  0   1 419   0   0   0]
#  [  0   0   0 411  79   1]
#  [  0   0   0  58 474   0]
#  [  0   0   0   0   0 537]]
# 0.9389209365456397
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       496
#            1       0.99      0.95      0.97       471
#            2       0.92      1.00      0.96       420
#            3       0.88      0.84      0.86       491
#            4       0.86      0.89      0.87       532
#            5       1.00      1.00      1.00       537
#
#     accuracy                           0.94      2947
#    macro avg       0.94      0.94      0.94      2947
# weighted avg       0.94      0.94      0.94      2947
# <Axes: >

# %%
pip install --upgrade mne packaging
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mne in /usr/local/lib/python3.10/dist-packages (0.20.5)
# Collecting mne
#   Downloading mne-1.8.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (23.2)
# Collecting packaging
#   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (5.1.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (2.11.3)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne) (0.3)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.10/dist-packages (from mne) (3.8.3)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from mne) (1.24.4)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.8.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from mne) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.66.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (4.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib>=3.6->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2023.11.17)
# Downloading mne-1.8.0-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 18.8 MB/s eta 0:00:0000:0100:01
# Downloading packaging-24.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 14.3 MB/s eta 0:00:00
# Installing collected packages: packaging, mne
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 2.11.1 requires packaging<24, but you have packaging 24.1 which is incompatible.
# rapids-dask-dependency 23.12.1 requires dask==2023.11.0, but you have dask 2023.3.2 which is incompatible.
# rapids-dask-dependency 23.12.1 requires distributed==2023.11.0, but you have distributed 2023.3.2.1 which is incompatible.
# tensorflow-addons 0.22.0 requires typeguard<3.0.0,>=2.7, but you have typeguard 4.1.2 which is incompatible.
# Successfully installed mne-1.8.0 packaging-24.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
from sklearn.metrics import cohen_kappa_score
from sklearn.manifold import TSNE

import models  # Ensure models.py is in the same directory
from Physionet_DataLoad import load_physionet  # Ensure Physionet_DataLoad.py is in the same directory

# %%
# %%
def draw_learning_curves(history, results_path):
    plt.figure()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'val'], loc='upper left')
    plt.savefig(results_path + '/ACC_' + '.png')
    plt.show()

    plt.figure()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'val'], loc='upper left')
    plt.savefig(results_path + '/LOSS_' + '.png')
    plt.show()
    plt.close()

def draw_confusion_matrix(cf_matrix, results_path):
    display_labels = ['Both feet', 'Left fist', 'Both fists', 'Right fist']
    disp = ConfusionMatrixDisplay(confusion_matrix=cf_matrix, display_labels=display_labels)
    disp.plot()
    disp.ax_.set_xticklabels(display_labels, rotation=12)
    plt.title('Confusion Matrix')
    plt.savefig(results_path + '/subject_' + '.png')
    plt.show()

# %%
# %%
def train(dataset_conf, train_conf, results_path):
    in_exp = time.time()
    best_models = open(results_path + "/best_models.txt", "w")
    log_write = open(results_path + "/log.txt", "w")
    perf_allRuns = open(results_path + "/perf_allRuns.npz", 'wb')

    data_path = dataset_conf.get('data_path')
    batch_size = train_conf.get('batch_size')
    epochs = train_conf.get('epochs')
    patience = train_conf.get('patience')
    lr = train_conf.get('lr')
    LearnCurves = train_conf.get('LearnCurves')
    model_name = train_conf.get('model')

    print('Training model: ', model_name)

    X_train, y_train_onehot, X_test, y_test_onehot = load_physionet(data_path)
    in_run = time.time()
    filepath = results_path + '/saved_models/run-1'
    os.makedirs(filepath, exist_ok=True)
    filepath = filepath + '/subject-1.h5'

    model = getModel(model_name)
    model.compile(loss=categorical_crossentropy, optimizer=Adam(learning_rate=lr), metrics=['accuracy'])
    callbacks = [
        ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='max'),
        EarlyStopping(monitor='val_accuracy', verbose=1, mode='max', patience=patience)
    ]
    history = model.fit(X_train, y_train_onehot, validation_data=(X_test, y_test_onehot),
                        epochs=epochs, batch_size=batch_size, callbacks=callbacks, verbose=1)

    model.load_weights(filepath)
    y_pred = model.predict(X_test).argmax(axis=-1)
    labels = y_test_onehot.argmax(axis=-1)
    acc = accuracy_score(labels, y_pred)
    kappa = cohen_kappa_score(labels, y_pred)

    out_run = time.time()
    info = f'Subject: 1   Train no. 1   Time: {(out_run - in_run) / 60:.3f} m   Test_acc: {acc:.5f}   Test_kappa: {kappa:.5f}'
    print(info)
    log_write.write(info + '\n')

    best_run = np.argmax([acc])
    best_models.write(f'/saved_models/run-{best_run + 1}/subject-1.h5\n')
    out_sub = time.time()
    info = f'Subject: 1   best_run: {best_run + 1}   Time: {(out_sub - in_run) / 60:.3f} m   acc: {acc:.5f}'
    print(info)
    log_write.write(info + '\n')

    if LearnCurves:
        draw_learning_curves(history, results_path)

    np.savez(perf_allRuns, acc=acc, kappa=kappa)
    best_models.close()
    log_write.close()
    perf_allRuns.close()

    model = getModel(model_name)
    test(model, dataset_conf, results_path, X_test, y_test_onehot)

# %%
# %%
def test(model, dataset_conf, results_path, X_test, y_test_onehot):
    log_write = open(results_path + "/log.txt", "a")
    best_models = open(results_path + "/best_models.txt", "r")
    n_classes = dataset_conf.get('n_classes')
    cf_matrix = np.zeros([n_classes, n_classes])

    perf_allRuns = open(results_path + "/perf_allRuns.npz", 'rb')
    perf_arrays = np.load(perf_allRuns)
    acc_allRuns = perf_arrays['acc']
    kappa_allRuns = perf_arrays['kappa']

    filepath = best_models.readline().strip()
    model.load_weights(results_path + filepath)

    y_pred = model.predict(X_test).argmax(axis=-1)
    labels = y_test_onehot.argmax(axis=-1)
    acc_bestRun = accuracy_score(labels, y_pred)
    kappa_bestRun = cohen_kappa_score(labels, y_pred)
    cf_matrix[:, :] = confusion_matrix(labels, y_pred, normalize='pred')
    draw_confusion_matrix(cf_matrix, results_path)

    info = f'Subject: 1   best_run: 1   acc: {acc_bestRun:.5f}   kappa: {kappa_bestRun:.5f}   avg_acc: {np.average(acc_allRuns):.5f} +- {acc_allRuns.std():.5f}'
    print(info)
    log_write.write('\n' + info)

    log_write.close()

# %%
# %%
def getModel(model_name):
    if model_name == 'DB_ATCNet':
        model = models.DB_ATCNet(
            n_classes=4,
            in_chans=64,
            in_samples=640,
            eegn_F1=16,
            eegn_D=2,
            eegn_kernelSize=64,
            eegn_poolSize=7,
            eegn_dropout=0.3,
            drop1=0.35,
            depth1=2,
            depth2=4,
            n_windows=5,
            attention='mha',
            tcn_depth=2,
            tcn_kernelSize=4,
            tcn_filters=32,
            tcn_dropout=0.3,
            drop2=0.1,
            drop3=0.15,
            drop4=0.15,
            tcn_activation='elu',
        )
    # Add other model cases here
    else:
        raise Exception(f"'{model_name}' model is not supported yet!")
    return model

# %%
# %% 필요한 라이브러리 가져오기
import os
import time
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay, cohen_kappa_score
from sklearn.manifold import TSNE

import models
from Physionet_DataLoad import load_physionet


# %% 학습 곡선 그리기 함수
def draw_learning_curves(history, results_path):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'val'], loc='upper left')
    plt.savefig(os.path.join(results_path, 'ACC.png'))
    plt.show()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'val'], loc='upper left')
    plt.savefig(os.path.join(results_path, 'LOSS.png'))
    plt.show()
    plt.close()


# %% 혼동 행렬 그리기 함수
def draw_confusion_matrix(cf_matrix, results_path):
    display_labels = ['Both feet', 'Left fist', 'Both fists', 'Right fist']
    disp = ConfusionMatrixDisplay(confusion_matrix=cf_matrix, display_labels=display_labels)
    disp.plot()
    disp.ax_.set_xticklabels(display_labels, rotation=12)
    plt.title('Confusion Matrix')
    plt.savefig(os.path.join(results_path, 'subject.png'))
    plt.show()


# %% 학습 함수
def train(dataset_conf, train_conf, results_path):
    in_exp = time.time()
    os.makedirs(results_path, exist_ok=True)
    log_write = open(os.path.join(results_path, "log.txt"), "w")

    data_path = dataset_conf.get('data_path')
    batch_size = train_conf.get('batch_size')
    epochs = train_conf.get('epochs')
    patience = train_conf.get('patience')
    lr = train_conf.get('lr')
    LearnCurves = train_conf.get('LearnCurves')
    model_name = train_conf.get('model')

    print('Training model: ', model_name)

    in_sub = time.time()
    BestSubjAcc = 0
    bestTrainingHistory = []
    X_train, y_train_onehot, X_test, y_test_onehot = load_physionet(data_path)

    in_run = time.time()

    model = getModel(model_name)
    model.compile(loss=categorical_crossentropy, optimizer=Adam(learning_rate=lr), metrics=['accuracy'])
    callbacks = [
        EarlyStopping(monitor='val_accuracy', verbose=1, mode='max', patience=patience)
    ]
    history = model.fit(X_train, y_train_onehot, validation_data=(X_test, y_test_onehot),
                        epochs=epochs, batch_size=batch_size, callbacks=callbacks, verbose=1)

    y_pred = model.predict(X_test).argmax(axis=-1)
    labels = y_test_onehot.argmax(axis=-1)
    acc = accuracy_score(labels, y_pred)
    kappa = cohen_kappa_score(labels, y_pred)

    out_run = time.time()
    info = f'Subject: 1   Train no. 1   Time: {(out_run - in_run) / 60:.3f} m   Test_acc: {acc:.5f}   Test_kappa: {kappa:.5f}'
    print(info)
    log_write.write(info + '\n')

    if BestSubjAcc < acc:
        BestSubjAcc = acc
        bestTrainingHistory = history

    out_sub = time.time()
    info = f'----------\nSubject: 1   best_run: 1   Time: {(out_sub - in_sub) / 60:.3f} m   acc: {acc:.5f}   avg_acc: {acc:.5f}   kappa: {kappa:.5f}\n----------'
    print(info)
    log_write.write(info + '\n')

    if LearnCurves:
        draw_learning_curves(bestTrainingHistory, results_path)

    out_exp = time.time()
    info = f'\nTime: {(out_exp - in_exp) / (60 * 60):.3f} h'
    print(info)
    log_write.write(info + '\n')
    log_write.close()

    test(model, dataset_conf, results_path, X_test, y_test_onehot)


# %% 평가 함수
def test(model, dataset_conf, results_path, X_test, y_test_onehot):
    log_write = open(os.path.join(results_path, "log.txt"), "a")
    n_classes = dataset_conf.get('n_classes')

    cf_matrix = np.zeros([n_classes, n_classes])
    y_pred = model.predict(X_test).argmax(axis=-1)
    labels = y_test_onehot.argmax(axis=-1)
    acc_bestRun = accuracy_score(labels, y_pred)
    kappa_bestRun = cohen_kappa_score(labels, y_pred)
    cf_matrix[:, :] = confusion_matrix(labels, y_pred, normalize='pred')
    draw_confusion_matrix(cf_matrix, results_path)

    info = f'Subject: 1   best_run: 1  acc: {acc_bestRun:.5f}   kappa: {kappa_bestRun:.5f}'
    print(info)
    log_write.write('\n' + info)
    log_write.close()


# %% 모델 가져오기 함수
def getModel(model_name):
    if model_name == 'DB_ATCNet':
        model = models.DB_ATCNet(
            n_classes=4,
            in_chans=64,
            in_samples=640,
            eegn_F1=16,
            eegn_D=2,
            eegn_kernelSize=64,
            eegn_poolSize=7,
            eegn_dropout=0.3,
            drop1=0.35,
            depth1=2,
            depth2=4,
            n_windows=5,
            attention='mha',
            tcn_depth=2,
            tcn_kernelSize=4,
            tcn_filters=32,
            tcn_dropout=0.3,
            drop2=0.1,
            drop3=0.15,
            drop4=0.15,
            tcn_activation='elu',
        )
    else:
        raise Exception(f"'{model_name}' model is not supported yet!")
    return model


# %% 실행 함수
def run():
    data_path = "motors/eeg_motor_files"
    results_path = os.path.join(os.getcwd(), "results")
    os.makedirs(results_path, exist_ok=True)

    dataset_conf = {'n_classes': 4, 'n_channels': 64, 'data_path': data_path}
    train_conf = {'batch_size': 32, 'epochs': 500, 'patience': 100, 'lr': 0.0009, 'LearnCurves': True, 'model': 'DB_ATCNet'}

    model = getModel(train_conf.get('model'))
    model.summary()

    train(dataset_conf, train_conf, results_path)


# %% Jupyter 환경에서 실행
if __name__ == "__main__":
    run()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 1, 64, 640)]         0         []
#
#  permute_4 (Permute)         (None, 640, 64, 1)           0         ['input_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 640, 64, 16)          1024      ['permute_4[0][0]']
#
#  batch_normalization_100 (B  (None, 640, 64, 16)          64        ['conv2d_12[0][0]']
#  atchNormalization)
#
#  global_average_pooling2d_8  (None, 16)                   0         ['batch_normalization_100[0][0
#   (GlobalAveragePooling2D)                                          ]']
#
#  reshape_16 (Reshape)        (None, 16, 1)                0         ['global_average_pooling2d_8[0
#                                                                     ][0]']
#
#  conv1d_88 (Conv1D)          (None, 16, 1)                3         ['reshape_16[0][0]']
#
#  tf.math.sigmoid_8 (TFOpLam  (None, 16, 1)                0         ['conv1d_88[0][0]']
#  bda)
#
#  reshape_17 (Reshape)        (None, 1, 1, 16)             0         ['tf.math.sigmoid_8[0][0]']
#
#  multiply_8 (Multiply)       (None, 640, 64, 16)          0         ['batch_normalization_100[0][0
#                                                                     ]',
#                                                                      'reshape_17[0][0]']
#
#  depthwise_conv2d_8 (Depthw  (None, 640, 1, 32)           2048      ['multiply_8[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_9 (Depthw  (None, 640, 1, 64)           4096      ['multiply_8[0][0]']
#  iseConv2D)
#
#  batch_normalization_101 (B  (None, 640, 1, 32)           128       ['depthwise_conv2d_8[0][0]']
#  atchNormalization)
#
#  batch_normalization_103 (B  (None, 640, 1, 64)           256       ['depthwise_conv2d_9[0][0]']
#  atchNormalization)
#
#  activation_136 (Activation  (None, 640, 1, 32)           0         ['batch_normalization_101[0][0
#  )                                                                  ]']
#
#  activation_138 (Activation  (None, 640, 1, 64)           0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  average_pooling2d_16 (Aver  (None, 80, 1, 32)            0         ['activation_136[0][0]']
#  agePooling2D)
#
#  average_pooling2d_18 (Aver  (None, 80, 1, 64)            0         ['activation_138[0][0]']
#  agePooling2D)
#
#  dropout_180 (Dropout)       (None, 80, 1, 32)            0         ['average_pooling2d_16[0][0]']
#
#  dropout_182 (Dropout)       (None, 80, 1, 64)            0         ['average_pooling2d_18[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 80, 1, 32)            16384     ['dropout_180[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 80, 1, 32)            32768     ['dropout_182[0][0]']
#
#  batch_normalization_102 (B  (None, 80, 1, 32)            128       ['conv2d_13[0][0]']
#  atchNormalization)
#
#  batch_normalization_104 (B  (None, 80, 1, 32)            128       ['conv2d_14[0][0]']
#  atchNormalization)
#
#  activation_137 (Activation  (None, 80, 1, 32)            0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  activation_139 (Activation  (None, 80, 1, 32)            0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  average_pooling2d_17 (Aver  (None, 11, 1, 32)            0         ['activation_137[0][0]']
#  agePooling2D)
#
#  average_pooling2d_19 (Aver  (None, 11, 1, 32)            0         ['activation_139[0][0]']
#  agePooling2D)
#
#  dropout_181 (Dropout)       (None, 11, 1, 32)            0         ['average_pooling2d_17[0][0]']
#
#  dropout_183 (Dropout)       (None, 11, 1, 32)            0         ['average_pooling2d_19[0][0]']
#  add_84 (Add)                (None, 11, 1, 32)            0         ['dropout_181[0][0]',
#                                                                      'dropout_183[0][0]']
#
#  dropout_184 (Dropout)       (None, 11, 1, 32)            0         ['add_84[0][0]']
#
#  global_average_pooling2d_9  (None, 32)                   0         ['dropout_184[0][0]']
#   (GlobalAveragePooling2D)
#
#  reshape_18 (Reshape)        (None, 32, 1)                0         ['global_average_pooling2d_9[0
#                                                                     ][0]']
#
#  conv1d_89 (Conv1D)          (None, 32, 1)                3         ['reshape_18[0][0]']
#
#  tf.math.sigmoid_9 (TFOpLam  (None, 32, 1)                0         ['conv1d_89[0][0]']
#  bda)
#
#  reshape_19 (Reshape)        (None, 1, 1, 32)             0         ['tf.math.sigmoid_9[0][0]']
#
#  multiply_9 (Multiply)       (None, 11, 1, 32)            0         ['dropout_184[0][0]',
#                                                                      'reshape_19[0][0]']
#
#  lambda_24 (Lambda)          (None, 11, 32)               0         ['multiply_9[0][0]']
#
#  tf.__operators__.getitem_2  (None, 7, 32)                0         ['lambda_24[0][0]']
#  0 (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, 7, 32)                0         ['lambda_24[0][0]']
#  1 (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, 7, 32)                0         ['lambda_24[0][0]']
#  2 (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, 7, 32)                0         ['lambda_24[0][0]']
#  3 (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, 7, 32)                0         ['lambda_24[0][0]']
#  4 (SlicingOpLambda)
#
#  layer_normalization_20 (La  (None, 7, 32)                64        ['tf.__operators__.getitem_20[
#  yerNormalization)                                                  0][0]']
#
#  layer_normalization_21 (La  (None, 7, 32)                64        ['tf.__operators__.getitem_21[
#  yerNormalization)                                                  0][0]']
#
#  layer_normalization_22 (La  (None, 7, 32)                64        ['tf.__operators__.getitem_22[
#  yerNormalization)                                                  0][0]']
#
#  layer_normalization_23 (La  (None, 7, 32)                64        ['tf.__operators__.getitem_23[
#  yerNormalization)                                                  0][0]']
#
#  layer_normalization_24 (La  (None, 7, 32)                64        ['tf.__operators__.getitem_24[
#  yerNormalization)                                                  0][0]']
#
#  multi_head_attention_20 (M  (None, 7, 32)                2128      ['layer_normalization_20[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_20[0][0]
#                                                                     ']
#
#  multi_head_attention_21 (M  (None, 7, 32)                2128      ['layer_normalization_21[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_21[0][0]
#                                                                     ']
#
#  multi_head_attention_22 (M  (None, 7, 32)                2128      ['layer_normalization_22[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_22[0][0]
#                                                                     ']
#
#  multi_head_attention_23 (M  (None, 7, 32)                2128      ['layer_normalization_23[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_23[0][0]
#                                                                     ']
#
#  multi_head_attention_24 (M  (None, 7, 32)                2128      ['layer_normalization_24[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_24[0][0]
#                                                                     ']
#
#  dropout_185 (Dropout)       (None, 7, 32)                0         ['multi_head_attention_20[0][0
#                                                                     ]']
#
#  dropout_193 (Dropout)       (None, 7, 32)                0         ['multi_head_attention_21[0][0
#                                                                     ]']
#
#  dropout_201 (Dropout)       (None, 7, 32)                0         ['multi_head_attention_22[0][0
#                                                                     ]']
#
#  dropout_209 (Dropout)       (None, 7, 32)                0         ['multi_head_attention_23[0][0
#                                                                     ]']
#
#  dropout_217 (Dropout)       (None, 7, 32)                0         ['multi_head_attention_24[0][0
#                                                                     ]']
#
#  add_85 (Add)                (None, 7, 32)                0         ['tf.__operators__.getitem_20[
#                                                                     0][0]',
#                                                                      'dropout_185[0][0]']
#
#  add_89 (Add)                (None, 7, 32)                0         ['tf.__operators__.getitem_21[
#                                                                     0][0]',
#                                                                      'dropout_193[0][0]']
#
#  add_93 (Add)                (None, 7, 32)                0         ['tf.__operators__.getitem_22[
#                                                                     0][0]',
#                                                                      'dropout_201[0][0]']
#
#  add_97 (Add)                (None, 7, 32)                0         ['tf.__operators__.getitem_23[
#                                                                     0][0]',
#                                                                      'dropout_209[0][0]']
#
#  add_101 (Add)               (None, 7, 32)                0         ['tf.__operators__.getitem_24[
#                                                                     0][0]',
#                                                                      'dropout_217[0][0]']
#
#  conv1d_90 (Conv1D)          (None, 7, 32)                4128      ['add_85[0][0]']
#
#  conv1d_94 (Conv1D)          (None, 7, 32)                4128      ['add_89[0][0]']
#
#  conv1d_98 (Conv1D)          (None, 7, 32)                4128      ['add_93[0][0]']
#
#  conv1d_102 (Conv1D)         (None, 7, 32)                4128      ['add_97[0][0]']
#
#  conv1d_106 (Conv1D)         (None, 7, 32)                4128      ['add_101[0][0]']
#
#  batch_normalization_105 (B  (None, 7, 32)                128       ['conv1d_90[0][0]']
#  atchNormalization)
#
#  batch_normalization_109 (B  (None, 7, 32)                128       ['conv1d_94[0][0]']
#  atchNormalization)
#
#  batch_normalization_113 (B  (None, 7, 32)                128       ['conv1d_98[0][0]']
#  atchNormalization)
#
#  batch_normalization_117 (B  (None, 7, 32)                128       ['conv1d_102[0][0]']
#  atchNormalization)
#
#  batch_normalization_121 (B  (None, 7, 32)                128       ['conv1d_106[0][0]']
#  atchNormalization)
#
#  activation_140 (Activation  (None, 7, 32)                0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  activation_146 (Activation  (None, 7, 32)                0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  activation_152 (Activation  (None, 7, 32)                0         ['batch_normalization_113[0][0
#  )                                                                  ]']
#
#  activation_158 (Activation  (None, 7, 32)                0         ['batch_normalization_117[0][0
#  )                                                                  ]']
#
#  activation_164 (Activation  (None, 7, 32)                0         ['batch_normalization_121[0][0
#  )                                                                  ]']
#
#  dropout_186 (Dropout)       (None, 7, 32)                0         ['activation_140[0][0]']
#
#  dropout_194 (Dropout)       (None, 7, 32)                0         ['activation_146[0][0]']
#
#  dropout_202 (Dropout)       (None, 7, 32)                0         ['activation_152[0][0]']
#
#  dropout_210 (Dropout)       (None, 7, 32)                0         ['activation_158[0][0]']
#
#  dropout_218 (Dropout)       (None, 7, 32)                0         ['activation_164[0][0]']
#
#  conv1d_91 (Conv1D)          (None, 7, 32)                4128      ['dropout_186[0][0]']
#
#  conv1d_95 (Conv1D)          (None, 7, 32)                4128      ['dropout_194[0][0]']
#
#  conv1d_99 (Conv1D)          (None, 7, 32)                4128      ['dropout_202[0][0]']
#
#  conv1d_103 (Conv1D)         (None, 7, 32)                4128      ['dropout_210[0][0]']
#
#  conv1d_107 (Conv1D)         (None, 7, 32)                4128      ['dropout_218[0][0]']
#
#  batch_normalization_106 (B  (None, 7, 32)                128       ['conv1d_91[0][0]']
#  atchNormalization)
#
#  batch_normalization_110 (B  (None, 7, 32)                128       ['conv1d_95[0][0]']
#  atchNormalization)
#
#  batch_normalization_114 (B  (None, 7, 32)                128       ['conv1d_99[0][0]']
#  atchNormalization)
#
#  batch_normalization_118 (B  (None, 7, 32)                128       ['conv1d_103[0][0]']
#  atchNormalization)
#
#  batch_normalization_122 (B  (None, 7, 32)                128       ['conv1d_107[0][0]']
#  atchNormalization)
#
#  activation_141 (Activation  (None, 7, 32)                0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  activation_147 (Activation  (None, 7, 32)                0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  activation_153 (Activation  (None, 7, 32)                0         ['batch_normalization_114[0][0
#  )                                                                  ]']
#
#  activation_159 (Activation  (None, 7, 32)                0         ['batch_normalization_118[0][0
#  )                                                                  ]']
#
#  activation_165 (Activation  (None, 7, 32)                0         ['batch_normalization_122[0][0
#  )                                                                  ]']
#
#  dropout_187 (Dropout)       (None, 7, 32)                0         ['activation_141[0][0]']
#
#  dropout_188 (Dropout)       (None, 7, 32)                0         ['add_85[0][0]']
#
#  dropout_195 (Dropout)       (None, 7, 32)                0         ['activation_147[0][0]']
#
#  dropout_196 (Dropout)       (None, 7, 32)                0         ['add_89[0][0]']
#
#  dropout_203 (Dropout)       (None, 7, 32)                0         ['activation_153[0][0]']
#
#  dropout_204 (Dropout)       (None, 7, 32)                0         ['add_93[0][0]']
#
#  dropout_211 (Dropout)       (None, 7, 32)                0         ['activation_159[0][0]']
#
#  dropout_212 (Dropout)       (None, 7, 32)                0         ['add_97[0][0]']
#
#  dropout_219 (Dropout)       (None, 7, 32)                0         ['activation_165[0][0]']
#
#  dropout_220 (Dropout)       (None, 7, 32)                0         ['add_101[0][0]']
#
#  add_86 (Add)                (None, 7, 32)                0         ['dropout_187[0][0]',
#                                                                      'dropout_188[0][0]']
#
#  add_90 (Add)                (None, 7, 32)                0         ['dropout_195[0][0]',
#                                                                      'dropout_196[0][0]']
#
#  add_94 (Add)                (None, 7, 32)                0         ['dropout_203[0][0]',
#                                                                      'dropout_204[0][0]']
#
#  add_98 (Add)                (None, 7, 32)                0         ['dropout_211[0][0]',
#                                                                      'dropout_212[0][0]']
#
#  add_102 (Add)               (None, 7, 32)                0         ['dropout_219[0][0]',
#                                                                      'dropout_220[0][0]']
#
#  activation_142 (Activation  (None, 7, 32)                0         ['add_86[0][0]']
#  )
#
#  activation_148 (Activation  (None, 7, 32)                0         ['add_90[0][0]']
#  )
#
#  activation_154 (Activation  (None, 7, 32)                0         ['add_94[0][0]']
#  )
#
#  activation_160 (Activation  (None, 7, 32)                0         ['add_98[0][0]']
#  )
#
#  activation_166 (Activation  (None, 7, 32)                0         ['add_102[0][0]']
#  )
#
#  conv1d_92 (Conv1D)          (None, 7, 32)                4128      ['activation_142[0][0]']
#
#  conv1d_96 (Conv1D)          (None, 7, 32)                4128      ['activation_148[0][0]']
#
#  conv1d_100 (Conv1D)         (None, 7, 32)                4128      ['activation_154[0][0]']
#
#  conv1d_104 (Conv1D)         (None, 7, 32)                4128      ['activation_160[0][0]']
#
#  conv1d_108 (Conv1D)         (None, 7, 32)                4128      ['activation_166[0][0]']
#
#  batch_normalization_107 (B  (None, 7, 32)                128       ['conv1d_92[0][0]']
#  atchNormalization)
#
#  batch_normalization_111 (B  (None, 7, 32)                128       ['conv1d_96[0][0]']
#  atchNormalization)
#
#  batch_normalization_115 (B  (None, 7, 32)                128       ['conv1d_100[0][0]']
#  atchNormalization)
#
#  batch_normalization_119 (B  (None, 7, 32)                128       ['conv1d_104[0][0]']
#  atchNormalization)
#
#  batch_normalization_123 (B  (None, 7, 32)                128       ['conv1d_108[0][0]']
#  atchNormalization)
#
#  activation_143 (Activation  (None, 7, 32)                0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  activation_149 (Activation  (None, 7, 32)                0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  activation_155 (Activation  (None, 7, 32)                0         ['batch_normalization_115[0][0
#  )                                                                  ]']
#
#  activation_161 (Activation  (None, 7, 32)                0         ['batch_normalization_119[0][0
#  )                                                                  ]']
#
#  activation_167 (Activation  (None, 7, 32)                0         ['batch_normalization_123[0][0
#  )                                                                  ]']
#
#  dropout_189 (Dropout)       (None, 7, 32)                0         ['activation_143[0][0]']
#
#  dropout_190 (Dropout)       (None, 7, 32)                0         ['dropout_188[0][0]']
#
#  dropout_197 (Dropout)       (None, 7, 32)                0         ['activation_149[0][0]']
#
#  dropout_198 (Dropout)       (None, 7, 32)                0         ['dropout_196[0][0]']
#
#  dropout_205 (Dropout)       (None, 7, 32)                0         ['activation_155[0][0]']
#
#  dropout_206 (Dropout)       (None, 7, 32)                0         ['dropout_204[0][0]']
#
#  dropout_213 (Dropout)       (None, 7, 32)                0         ['activation_161[0][0]']
#
#  dropout_214 (Dropout)       (None, 7, 32)                0         ['dropout_212[0][0]']
#
#  dropout_221 (Dropout)       (None, 7, 32)                0         ['activation_167[0][0]']
#
#  dropout_222 (Dropout)       (None, 7, 32)                0         ['dropout_220[0][0]']
#
#  add_87 (Add)                (None, 7, 32)                0         ['dropout_189[0][0]',
#                                                                      'dropout_190[0][0]']
#
#  add_91 (Add)                (None, 7, 32)                0         ['dropout_197[0][0]',
#                                                                      'dropout_198[0][0]']
#
#  add_95 (Add)                (None, 7, 32)                0         ['dropout_205[0][0]',
#                                                                      'dropout_206[0][0]']
#
#  add_99 (Add)                (None, 7, 32)                0         ['dropout_213[0][0]',
#                                                                      'dropout_214[0][0]']
#
#  add_103 (Add)               (None, 7, 32)                0         ['dropout_221[0][0]',
#                                                                      'dropout_222[0][0]']
#
#  conv1d_93 (Conv1D)          (None, 7, 32)                4128      ['add_87[0][0]']
#
#  conv1d_97 (Conv1D)          (None, 7, 32)                4128      ['add_91[0][0]']
#  conv1d_101 (Conv1D)         (None, 7, 32)                4128      ['add_95[0][0]']
#
#  conv1d_105 (Conv1D)         (None, 7, 32)                4128      ['add_99[0][0]']
#
#  conv1d_109 (Conv1D)         (None, 7, 32)                4128      ['add_103[0][0]']
#
#  batch_normalization_108 (B  (None, 7, 32)                128       ['conv1d_93[0][0]']
#  atchNormalization)
#
#  batch_normalization_112 (B  (None, 7, 32)                128       ['conv1d_97[0][0]']
#  atchNormalization)
#
#  batch_normalization_116 (B  (None, 7, 32)                128       ['conv1d_101[0][0]']
#  atchNormalization)
#
#  batch_normalization_120 (B  (None, 7, 32)                128       ['conv1d_105[0][0]']
#  atchNormalization)
#
#  batch_normalization_124 (B  (None, 7, 32)                128       ['conv1d_109[0][0]']
#  atchNormalization)
#
#  activation_144 (Activation  (None, 7, 32)                0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  activation_150 (Activation  (None, 7, 32)                0         ['batch_normalization_112[0][0
#  )                                                                  ]']
#
#  activation_156 (Activation  (None, 7, 32)                0         ['batch_normalization_116[0][0
#  )                                                                  ]']
#
#  activation_162 (Activation  (None, 7, 32)                0         ['batch_normalization_120[0][0
#  )                                                                  ]']
#
#  activation_168 (Activation  (None, 7, 32)                0         ['batch_normalization_124[0][0
#  )                                                                  ]']
#
#  dropout_191 (Dropout)       (None, 7, 32)                0         ['activation_144[0][0]']
#
#  dropout_192 (Dropout)       (None, 7, 32)                0         ['dropout_190[0][0]']
#
#  dropout_199 (Dropout)       (None, 7, 32)                0         ['activation_150[0][0]']
#
#  dropout_200 (Dropout)       (None, 7, 32)                0         ['dropout_198[0][0]']
#
#  dropout_207 (Dropout)       (None, 7, 32)                0         ['activation_156[0][0]']
#
#  dropout_208 (Dropout)       (None, 7, 32)                0         ['dropout_206[0][0]']
#
#  dropout_215 (Dropout)       (None, 7, 32)                0         ['activation_162[0][0]']
#
#  dropout_216 (Dropout)       (None, 7, 32)                0         ['dropout_214[0][0]']
#
#  dropout_223 (Dropout)       (None, 7, 32)                0         ['activation_168[0][0]']
#
#  dropout_224 (Dropout)       (None, 7, 32)                0         ['dropout_222[0][0]']
#
#  add_88 (Add)                (None, 7, 32)                0         ['dropout_191[0][0]',
#                                                                      'dropout_192[0][0]']
#
#  add_92 (Add)                (None, 7, 32)                0         ['dropout_199[0][0]',
#                                                                      'dropout_200[0][0]']
#
#  add_96 (Add)                (None, 7, 32)                0         ['dropout_207[0][0]',
#                                                                      'dropout_208[0][0]']
#
#  add_100 (Add)               (None, 7, 32)                0         ['dropout_215[0][0]',
#                                                                      'dropout_216[0][0]']
#
#  add_104 (Add)               (None, 7, 32)                0         ['dropout_223[0][0]',
#                                                                      'dropout_224[0][0]']
#
#  activation_145 (Activation  (None, 7, 32)                0         ['add_88[0][0]']
#  )
# ...
# Epoch 84/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7302 - accuracy: 0.7169 - val_loss: 0.9075 - val_accuracy: 0.6595
# Epoch 85/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.7290 - accuracy: 0.7160 - val_loss: 0.9143 - val_accuracy: 0.6519
# Epoch 86/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7296 - accuracy: 0.7179 - val_loss: 0.9054 - val_accuracy: 0.6519
# Epoch 87/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7233 - accuracy: 0.7169 - val_loss: 0.9070 - val_accuracy: 0.6465
# Epoch 88/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7242 - accuracy: 0.7215 - val_loss: 0.9038 - val_accuracy: 0.6443
# Epoch 89/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7262 - accuracy: 0.7185 - val_loss: 0.8860 - val_accuracy: 0.6703
# Epoch 90/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7203 - accuracy: 0.7215 - val_loss: 0.9405 - val_accuracy: 0.6432
# Epoch 91/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7179 - accuracy: 0.7205 - val_loss: 0.9244 - val_accuracy: 0.6530
# Epoch 92/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7132 - accuracy: 0.7232 - val_loss: 0.9045 - val_accuracy: 0.6692
# Epoch 93/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7098 - accuracy: 0.7249 - val_loss: 0.9680 - val_accuracy: 0.6454
# Epoch 94/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7120 - accuracy: 0.7196 - val_loss: 0.9184 - val_accuracy: 0.6530
# Epoch 95/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.7160 - accuracy: 0.7193 - val_loss: 0.8969 - val_accuracy: 0.6670
# Epoch 96/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.7191 - accuracy: 0.7167 - val_loss: 0.9301 - val_accuracy: 0.6562
# Epoch 97/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.7134 - accuracy: 0.7257 - val_loss: 0.9162 - val_accuracy: 0.6714
# Epoch 98/500
# 260/260 [==============================] - 12s 48ms/step - loss: 0.7195 - accuracy: 0.7202 - val_loss: 0.9336 - val_accuracy: 0.6541
# Epoch 99/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7111 - accuracy: 0.7239 - val_loss: 0.9351 - val_accuracy: 0.6541
# Epoch 100/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.7033 - accuracy: 0.7235 - val_loss: 0.9257 - val_accuracy: 0.6465
# Epoch 101/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7087 - accuracy: 0.7272 - val_loss: 0.8936 - val_accuracy: 0.6562
# Epoch 102/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.7103 - accuracy: 0.7291 - val_loss: 0.9932 - val_accuracy: 0.6130
# Epoch 103/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.7088 - accuracy: 0.7278 - val_loss: 0.9296 - val_accuracy: 0.6530
# Epoch 104/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7071 - accuracy: 0.7276 - val_loss: 0.9254 - val_accuracy: 0.6443
# Epoch 105/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7139 - accuracy: 0.7223 - val_loss: 0.9544 - val_accuracy: 0.6227
# Epoch 106/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6942 - accuracy: 0.7286 - val_loss: 0.9373 - val_accuracy: 0.6551
# Epoch 107/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.7075 - accuracy: 0.7299 - val_loss: 0.9039 - val_accuracy: 0.6443
# Epoch 108/500
# 260/260 [==============================] - 12s 48ms/step - loss: 0.6988 - accuracy: 0.7244 - val_loss: 0.9259 - val_accuracy: 0.6573
# Epoch 109/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6970 - accuracy: 0.7302 - val_loss: 0.9024 - val_accuracy: 0.6670
# Epoch 110/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.7010 - accuracy: 0.7294 - val_loss: 0.8954 - val_accuracy: 0.6541
# Epoch 111/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6900 - accuracy: 0.7320 - val_loss: 0.9261 - val_accuracy: 0.6432
# Epoch 112/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6892 - accuracy: 0.7304 - val_loss: 0.9016 - val_accuracy: 0.6584
# Epoch 113/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6919 - accuracy: 0.7296 - val_loss: 0.9017 - val_accuracy: 0.6595
# Epoch 114/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6897 - accuracy: 0.7322 - val_loss: 0.9222 - val_accuracy: 0.6519
# Epoch 115/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.7014 - accuracy: 0.7263 - val_loss: 0.9579 - val_accuracy: 0.6357
# Epoch 116/500
# 260/260 [==============================] - 13s 50ms/step - loss: 0.6740 - accuracy: 0.7403 - val_loss: 0.9652 - val_accuracy: 0.6368
# Epoch 117/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6897 - accuracy: 0.7350 - val_loss: 0.9312 - val_accuracy: 0.6519
# Epoch 118/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6809 - accuracy: 0.7376 - val_loss: 0.9258 - val_accuracy: 0.6584
# Epoch 119/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6858 - accuracy: 0.7385 - val_loss: 0.9286 - val_accuracy: 0.6519
# Epoch 120/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6824 - accuracy: 0.7336 - val_loss: 0.9696 - val_accuracy: 0.6378
# Epoch 121/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6785 - accuracy: 0.7370 - val_loss: 0.8967 - val_accuracy: 0.6584
# Epoch 122/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6802 - accuracy: 0.7363 - val_loss: 0.9324 - val_accuracy: 0.6627
# Epoch 123/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6722 - accuracy: 0.7373 - val_loss: 0.9244 - val_accuracy: 0.6562
# Epoch 124/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6747 - accuracy: 0.7410 - val_loss: 0.9240 - val_accuracy: 0.6573
# Epoch 125/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6819 - accuracy: 0.7296 - val_loss: 0.9229 - val_accuracy: 0.6605
# Epoch 126/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6788 - accuracy: 0.7382 - val_loss: 0.9345 - val_accuracy: 0.6562
# Epoch 127/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6662 - accuracy: 0.7376 - val_loss: 0.9581 - val_accuracy: 0.6400
# Epoch 128/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6794 - accuracy: 0.7351 - val_loss: 0.9311 - val_accuracy: 0.6432
# Epoch 129/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6843 - accuracy: 0.7329 - val_loss: 0.8958 - val_accuracy: 0.6497
# Epoch 130/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6787 - accuracy: 0.7369 - val_loss: 0.9154 - val_accuracy: 0.6508
# Epoch 131/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6746 - accuracy: 0.7375 - val_loss: 0.9726 - val_accuracy: 0.6389
# Epoch 132/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6864 - accuracy: 0.7341 - val_loss: 0.9456 - val_accuracy: 0.6476
# Epoch 133/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6723 - accuracy: 0.7439 - val_loss: 0.9234 - val_accuracy: 0.6551
# Epoch 134/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6667 - accuracy: 0.7443 - val_loss: 0.9146 - val_accuracy: 0.6486
# Epoch 135/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6596 - accuracy: 0.7430 - val_loss: 0.9525 - val_accuracy: 0.6454
# Epoch 136/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6622 - accuracy: 0.7429 - val_loss: 0.9258 - val_accuracy: 0.6465
# Epoch 137/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6731 - accuracy: 0.7382 - val_loss: 0.9375 - val_accuracy: 0.6368
# Epoch 138/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6647 - accuracy: 0.7464 - val_loss: 0.9261 - val_accuracy: 0.6638
# Epoch 139/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6710 - accuracy: 0.7406 - val_loss: 0.9079 - val_accuracy: 0.6627
# Epoch 140/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6485 - accuracy: 0.7507 - val_loss: 0.9168 - val_accuracy: 0.6432
# Epoch 141/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6634 - accuracy: 0.7484 - val_loss: 0.9644 - val_accuracy: 0.6454
# Epoch 142/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6570 - accuracy: 0.7457 - val_loss: 0.9527 - val_accuracy: 0.6454
# Epoch 143/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6617 - accuracy: 0.7459 - val_loss: 0.9267 - val_accuracy: 0.6497
# Epoch 144/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6647 - accuracy: 0.7403 - val_loss: 0.9025 - val_accuracy: 0.6670
# Epoch 145/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6683 - accuracy: 0.7380 - val_loss: 0.9374 - val_accuracy: 0.6508
# Epoch 146/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6566 - accuracy: 0.7394 - val_loss: 0.9313 - val_accuracy: 0.6465
# Epoch 147/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6518 - accuracy: 0.7495 - val_loss: 0.9485 - val_accuracy: 0.6422
# Epoch 148/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6626 - accuracy: 0.7459 - val_loss: 0.9133 - val_accuracy: 0.6551
# Epoch 149/500
# 260/260 [==============================] - 12s 48ms/step - loss: 0.6625 - accuracy: 0.7417 - val_loss: 0.9506 - val_accuracy: 0.6497
# Epoch 150/500
# 260/260 [==============================] - 12s 48ms/step - loss: 0.6623 - accuracy: 0.7440 - val_loss: 0.9193 - val_accuracy: 0.6486
# Epoch 151/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6564 - accuracy: 0.7476 - val_loss: 0.9296 - val_accuracy: 0.6422
# Epoch 152/500
# 260/260 [==============================] - 12s 48ms/step - loss: 0.6633 - accuracy: 0.7425 - val_loss: 0.9400 - val_accuracy: 0.6519
# Epoch 153/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6616 - accuracy: 0.7394 - val_loss: 0.9516 - val_accuracy: 0.6562
# Epoch 154/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6455 - accuracy: 0.7538 - val_loss: 0.9841 - val_accuracy: 0.6335
# Epoch 155/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6522 - accuracy: 0.7526 - val_loss: 0.9342 - val_accuracy: 0.6476
# Epoch 156/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6435 - accuracy: 0.7506 - val_loss: 0.9291 - val_accuracy: 0.6497
# Epoch 157/500
# 260/260 [==============================] - 13s 50ms/step - loss: 0.6588 - accuracy: 0.7471 - val_loss: 0.9085 - val_accuracy: 0.6497
# Epoch 158/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6515 - accuracy: 0.7504 - val_loss: 0.9234 - val_accuracy: 0.6508
# Epoch 159/500
# 260/260 [==============================] - 13s 50ms/step - loss: 0.6415 - accuracy: 0.7519 - val_loss: 0.9733 - val_accuracy: 0.6443
# Epoch 160/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6463 - accuracy: 0.7531 - val_loss: 0.9319 - val_accuracy: 0.6465
# Epoch 161/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6576 - accuracy: 0.7466 - val_loss: 0.9248 - val_accuracy: 0.6530
# Epoch 162/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6428 - accuracy: 0.7518 - val_loss: 0.9263 - val_accuracy: 0.6530
# Epoch 163/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6531 - accuracy: 0.7482 - val_loss: 0.9403 - val_accuracy: 0.6649
# Epoch 164/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6348 - accuracy: 0.7559 - val_loss: 1.0783 - val_accuracy: 0.6108
# Epoch 165/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6438 - accuracy: 0.7530 - val_loss: 0.9245 - val_accuracy: 0.6551
# Epoch 166/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6415 - accuracy: 0.7524 - val_loss: 0.9978 - val_accuracy: 0.6324
# Epoch 167/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6315 - accuracy: 0.7554 - val_loss: 0.9357 - val_accuracy: 0.6649
# Epoch 168/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6425 - accuracy: 0.7512 - val_loss: 0.9766 - val_accuracy: 0.6400
# Epoch 169/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6280 - accuracy: 0.7603 - val_loss: 0.9618 - val_accuracy: 0.6486
# Epoch 170/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6386 - accuracy: 0.7498 - val_loss: 0.9218 - val_accuracy: 0.6584
# Epoch 171/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6338 - accuracy: 0.7540 - val_loss: 0.9478 - val_accuracy: 0.6465
# Epoch 172/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6216 - accuracy: 0.7531 - val_loss: 0.9596 - val_accuracy: 0.6573
# Epoch 173/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6322 - accuracy: 0.7588 - val_loss: 0.9450 - val_accuracy: 0.6530
# Epoch 174/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6416 - accuracy: 0.7502 - val_loss: 0.9331 - val_accuracy: 0.6595
# Epoch 175/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6402 - accuracy: 0.7547 - val_loss: 0.9546 - val_accuracy: 0.6411
# Epoch 176/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6324 - accuracy: 0.7591 - val_loss: 0.9413 - val_accuracy: 0.6616
# Epoch 185/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6257 - accuracy: 0.7650 - val_loss: 0.9217 - val_accuracy: 0.6616
# Epoch 186/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6259 - accuracy: 0.7591 - val_loss: 0.9473 - val_accuracy: 0.6649
# Epoch 187/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6191 - accuracy: 0.7611 - val_loss: 0.9556 - val_accuracy: 0.6584
# Epoch 188/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6254 - accuracy: 0.7578 - val_loss: 0.9508 - val_accuracy: 0.6541
# Epoch 189/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6325 - accuracy: 0.7529 - val_loss: 0.9973 - val_accuracy: 0.6411
# Epoch 190/500
# 260/260 [==============================] - 13s 49ms/step - loss: 0.6196 - accuracy: 0.7567 - val_loss: 0.9696 - val_accuracy: 0.6616
# Epoch 191/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6222 - accuracy: 0.7606 - val_loss: 0.9362 - val_accuracy: 0.6595
# Epoch 192/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6084 - accuracy: 0.7619 - val_loss: 0.9470 - val_accuracy: 0.6519
# Epoch 193/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6042 - accuracy: 0.7627 - val_loss: 1.0021 - val_accuracy: 0.6324
# Epoch 194/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6265 - accuracy: 0.7600 - val_loss: 0.9540 - val_accuracy: 0.6551
# Epoch 195/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6080 - accuracy: 0.7650 - val_loss: 0.9119 - val_accuracy: 0.6670
# Epoch 196/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6288 - accuracy: 0.7557 - val_loss: 0.9803 - val_accuracy: 0.6368
# Epoch 197/500
# 260/260 [==============================] - 13s 48ms/step - loss: 0.6158 - accuracy: 0.7647 - val_loss: 0.9905 - val_accuracy: 0.6454
# Epoch 197: early stopping
# 29/29 [==============================] - 1s 8ms/step
# Subject: 1   Train no. 1   Time: 41.865 m   Test_acc: 0.64541   Test_kappa: 0.52728
# ----------
# Subject: 1   best_run: 1   Time: 43.188 m   acc: 0.64541   avg_acc: 0.64541   kappa: 0.52728
# ----------
# Time: 0.720 h
# 29/29 [==============================] - 0s 8ms/step
# Subject: 1   best_run: 1  acc: 0.64541   kappa: 0.52728

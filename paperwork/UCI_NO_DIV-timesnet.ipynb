# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model, Sequential
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
import keras.models
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns


def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values



# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y


# load the dataset, returns train and test X and y elements
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '/Users/ohheungchan/workspace/AI_Study/Paperwork/human+activity+recognition+using+smartphones/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '/Users/ohheungchan/workspace/AI_Study/Paperwork/human+activity+recognition+using+smartphones/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
# Out:
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /var/folders/9x/8whwzmnj6z5bjc7_h1txd9_r0000gn/T/ipykernel_65597/1700422476.py:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)

# %%
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)
# Out:
# X train shape:  (7352, 128, 9)
# Y train shape:  (7352, 1)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 9)
# Y test shape:  (2947, 1)
# Y test One hot shape:  (2947, 6)

# %%
print("0: Walking:" ,np.where(trainy == 0)[0].size)
print("1: WU:" ,np.where(trainy == 1)[0].size)
print("2: WD:" ,np.where(trainy == 2)[0].size)
print("3: Sitting:" ,np.where(trainy == 3)[0].size)
print("4: Standing:" ,np.where(trainy == 4)[0].size)
print("5: Laying:" ,np.where(trainy == 5)[0].size)
# Out:
# 0: Walking: 1226
# 1: WU: 1073
# 2: WD: 986
# 3: Sitting: 1286
# 4: Standing: 1374
# 5: Laying: 1407

# %%
unique, counts = np.unique(trainy, return_counts=True)
print ("Train data label statistics::")
print (np.asarray((unique, counts)).T)

unique, counts = np.unique(testy, return_counts=True)
print ("Test data label statistics::")
print (np.asarray((unique, counts)).T)
# Out:
# Train data label statistics::
# [[   0 1226]
#  [   1 1073]
#  [   2  986]
#  [   3 1286]
#  [   4 1374]
#  [   5 1407]]
# Test data label statistics::
# [[  0 496]
#  [  1 471]
#  [  2 420]
#  [  3 491]
#  [  4 532]
#  [  5 537]]

# %%
X_train_all = trainX   # at this stage, the data includes both dynamic and static HAR data
y_train_all = trainy

X_test_all = testX
y_test_all = testy

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.fft
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, confusion_matrix
import math

# Device 설정 (MPS, CUDA, CPU)
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print("Using device:", device)

# --- DataEmbedding ---
class DataEmbedding(nn.Module):
    def __init__(self, c_in, d_model, embed_type='fixed', freq='h', dropout=0.1):
        super(DataEmbedding, self).__init__()
        self.value_embedding = nn.Linear(c_in, d_model)
        self.dropout = nn.Dropout(dropout)
    def forward(self, x, x_mark):
        x = self.value_embedding(x)
        return self.dropout(x)

# --- Inception_Block_V1 ---
class Inception_Block_V1(nn.Module):
    def __init__(self, in_channels, out_channels, num_kernels=3):
        super(Inception_Block_V1, self).__init__()
        kernel_sizes = [3, 5, 7][:num_kernels]
        self.conv_branches = nn.ModuleList([
            nn.Conv2d(in_channels, out_channels, kernel_size=(1, k), padding=(0, k // 2))
            for k in kernel_sizes
        ])
    def forward(self, x):
        outputs = [conv(x) for conv in self.conv_branches]
        out = sum(outputs)
        return out

# --- FFT_for_Period 함수 ---
def FFT_for_Period(x, k=2):
    # x: [B, T, C]
    xf = torch.fft.rfft(x, dim=1)
    frequency_list = abs(xf).mean(0).mean(-1)
    frequency_list[0] = 0  # DC 성분 제외
    _, top_list = torch.topk(frequency_list, k)
    top_list = top_list.detach().cpu().numpy()
    period = x.shape[1] // top_list
    return period, abs(xf).mean(-1)[:, top_list]

# --- TimesBlock ---
class TimesBlock(nn.Module):
    def __init__(self, configs):
        super(TimesBlock, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.k = configs.top_k
        self.conv = nn.Sequential(
            Inception_Block_V1(configs.d_model, configs.d_ff, num_kernels=configs.num_kernels),
            nn.GELU(),
            Inception_Block_V1(configs.d_ff, configs.d_model, num_kernels=configs.num_kernels)
        )
    def forward(self, x):
        B, T, N = x.size()
        period_list, period_weight = FFT_for_Period(x, self.k)
        res = []
        for i in range(self.k):
            period = period_list[i]
            if (self.seq_len + self.pred_len) % period != 0:
                length = (((self.seq_len + self.pred_len) // period) + 1) * period
                padding = torch.zeros([x.shape[0], (length - (self.seq_len + self.pred_len)), x.shape[2]]).to(x.device)
                out = torch.cat([x, padding], dim=1)
            else:
                length = (self.seq_len + self.pred_len)
                out = x
            out = out.reshape(B, length // period, period, N).permute(0, 3, 1, 2).contiguous()
            out = self.conv(out)
            out = out.permute(0, 2, 3, 1).reshape(B, -1, N)
            res.append(out[:, :(self.seq_len + self.pred_len), :])
        res = torch.stack(res, dim=-1)
        period_weight = F.softmax(period_weight, dim=1)
        period_weight = period_weight.unsqueeze(1).unsqueeze(1).repeat(1, T, N, 1)
        res = torch.sum(res * period_weight, -1)
        res = res + x
        return res

# --- TimesNet Model ---
class Model(nn.Module):
    """
    TimesNet Model 구현 (분류 classification 태스크)
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.configs = configs
        self.task_name = configs.task_name
        self.seq_len = configs.seq_len
        self.label_len = configs.label_len
        self.pred_len = configs.pred_len
        self.model = nn.ModuleList([TimesBlock(configs) for _ in range(configs.e_layers)])
        self.enc_embedding = DataEmbedding(configs.enc_in, configs.d_model, configs.embed, configs.freq, configs.dropout)
        self.layer = configs.e_layers
        self.layer_norm = nn.LayerNorm(configs.d_model)
        if self.task_name == 'classification':
            self.act = F.gelu
            self.dropout = nn.Dropout(configs.dropout)
            self.projection = nn.Linear(configs.d_model * configs.seq_len, configs.num_class)
    def classification(self, x_enc, x_mark_enc):
        enc_out = self.enc_embedding(x_enc, None)
        for i in range(self.layer):
            enc_out = self.layer_norm(self.model[i](enc_out))
        output = self.act(enc_out)
        output = self.dropout(output)
        output = output * x_mark_enc.unsqueeze(-1)  # 여기서는 마스크를 모두 1로 가정
        output = output.reshape(output.shape[0], -1)
        output = self.projection(output)
        return output
    def forward(self, x_enc, x_mark_enc, x_dec, x_mark_dec, mask=None):
        if self.task_name == 'classification':
            dec_out = self.classification(x_enc, x_mark_enc)
            return dec_out
        return None

# --- Config 클래스 ---
class Config:
    def __init__(self):
        self.task_name = 'classification'
        self.seq_len = 128
        self.label_len = 128
        self.pred_len = 0
        self.e_layers = 3
        self.enc_in = 9
        self.d_model = 64
        self.embed = 'fixed'
        self.freq = 'h'
        self.dropout = 0.1
        self.d_ff = 256
        self.num_kernels = 3
        self.top_k = 2
        self.num_class = 12  # 원하는 분류 클래스 수
        self.c_out = 1

print("Model definitions loaded.")

# %%
from torch.utils.data import TensorDataset, DataLoader

# 이미 준비된 데이터를 사용 (trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot)
# 예시 출력 (이 변수들은 이미 메모리에 존재한다고 가정)
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)

# 레이블을 (N,) 형태로 변환
trainy = np.squeeze(trainy)
testy  = np.squeeze(testy)

# 텐서로 변환
X_train_tensor = torch.tensor(trainX, dtype=torch.float32)
X_test_tensor  = torch.tensor(testX, dtype=torch.float32)
y_train_tensor = torch.tensor(trainy, dtype=torch.long)
y_test_tensor  = torch.tensor(testy, dtype=torch.long)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset  = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 모델 인스턴스 생성
config = Config()
model = Model(config).to(device)
print(model)

# 학습 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 30

print("Training start...")
for epoch in range(num_epochs):
    # 학습 단계
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        # 마스크: 모두 1 (padding 없음 가정)
        mask = torch.ones(batch_X.size(0), batch_X.size(1)).to(device)
        outputs = model(batch_X, mask, None, None)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * batch_X.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch_y).sum().item()
        total += batch_y.size(0)
    epoch_loss = running_loss / total
    epoch_acc = 100.0 * correct / total

    # 검증 단계 (test_loader 사용)
    model.eval()
    running_val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for val_X, val_y in test_loader:
            val_X, val_y = val_X.to(device), val_y.to(device)
            mask_val = torch.ones(val_X.size(0), val_X.size(1)).to(device)
            outputs_val = model(val_X, mask_val, None, None)
            loss_val = criterion(outputs_val, val_y)
            running_val_loss += loss_val.item() * val_X.size(0)
            _, predicted_val = torch.max(outputs_val, 1)
            correct_val += (predicted_val == val_y).sum().item()
            total_val += val_y.size(0)
    val_loss = running_val_loss / total_val
    val_acc = 100.0 * correct_val / total_val

    print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.2f}%, " +
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")
# Out:
# X train shape:  (7352, 128, 9)
# Y train shape:  (7352, 1)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 9)
# Y test shape:  (2947, 1)
# Y test One hot shape:  (2947, 6)
# Model(
#   (model): ModuleList(
#     (0-2): 3 x TimesBlock(
#       (conv): Sequential(
#         (0): Inception_Block_V1(
#           (conv_branches): ModuleList(
#             (0): Conv2d(64, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#             (1): Conv2d(64, 256, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#             (2): Conv2d(64, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3))
#           )
#         )
#         (1): GELU(approximate='none')
#         (2): Inception_Block_V1(
#           (conv_branches): ModuleList(
#             (0): Conv2d(256, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#             (1): Conv2d(256, 64, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#             (2): Conv2d(256, 64, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3))
#           )
#         )
#       )
#     )
#   )
#   (enc_embedding): DataEmbedding(
#     (value_embedding): Linear(in_features=9, out_features=64, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (projection): Linear(in_features=8192, out_features=6, bias=True)
# )
# Training start...
# Epoch 1/30 - Train Loss: 1.0976, Train Acc: 55.06%, Val Loss: 0.7184, Val Acc: 72.38%
# Epoch 2/30 - Train Loss: 0.3972, Train Acc: 84.07%, Val Loss: 0.6480, Val Acc: 76.35%
# Epoch 3/30 - Train Loss: 0.2691, Train Acc: 89.00%, Val Loss: 0.5555, Val Acc: 82.63%
# Epoch 4/30 - Train Loss: 0.1869, Train Acc: 92.68%, Val Loss: 0.5206, Val Acc: 84.56%
# Epoch 5/30 - Train Loss: 0.1810, Train Acc: 93.20%, Val Loss: 0.3268, Val Acc: 89.35%
# Epoch 6/30 - Train Loss: 0.1617, Train Acc: 93.73%, Val Loss: 0.3770, Val Acc: 88.73%
# Epoch 7/30 - Train Loss: 0.1334, Train Acc: 94.34%, Val Loss: 0.5954, Val Acc: 86.97%
# Epoch 8/30 - Train Loss: 0.1451, Train Acc: 94.08%, Val Loss: 0.3467, Val Acc: 90.23%
# Epoch 9/30 - Train Loss: 0.1451, Train Acc: 94.15%, Val Loss: 0.4829, Val Acc: 86.26%
# Epoch 10/30 - Train Loss: 0.1164, Train Acc: 95.13%, Val Loss: 0.5417, Val Acc: 89.31%
# Epoch 11/30 - Train Loss: 0.1195, Train Acc: 95.29%, Val Loss: 0.5441, Val Acc: 90.30%
# Epoch 12/30 - Train Loss: 0.1211, Train Acc: 95.01%, Val Loss: 0.3246, Val Acc: 88.97%
# Epoch 13/30 - Train Loss: 0.1226, Train Acc: 95.10%, Val Loss: 0.4346, Val Acc: 89.62%
# Epoch 14/30 - Train Loss: 0.1622, Train Acc: 94.38%, Val Loss: 0.3731, Val Acc: 89.58%
# Epoch 15/30 - Train Loss: 0.1367, Train Acc: 94.41%, Val Loss: 0.4055, Val Acc: 88.87%
# Epoch 16/30 - Train Loss: 0.1286, Train Acc: 94.61%, Val Loss: 0.4647, Val Acc: 91.55%
# Epoch 17/30 - Train Loss: 0.1239, Train Acc: 95.02%, Val Loss: 0.4014, Val Acc: 91.01%
# Epoch 18/30 - Train Loss: 0.1063, Train Acc: 95.42%, Val Loss: 0.4395, Val Acc: 92.16%
# Epoch 19/30 - Train Loss: 0.1083, Train Acc: 95.53%, Val Loss: 0.3295, Val Acc: 91.72%
# Epoch 20/30 - Train Loss: 0.1102, Train Acc: 95.24%, Val Loss: 0.6295, Val Acc: 89.04%
# Epoch 21/30 - Train Loss: 0.1053, Train Acc: 95.35%, Val Loss: 0.7743, Val Acc: 90.16%
# Epoch 22/30 - Train Loss: 0.1030, Train Acc: 95.38%, Val Loss: 0.4844, Val Acc: 88.46%
# Epoch 23/30 - Train Loss: 0.1085, Train Acc: 95.35%, Val Loss: 0.6338, Val Acc: 88.43%
# Epoch 24/30 - Train Loss: 0.1044, Train Acc: 95.36%, Val Loss: 0.6045, Val Acc: 90.36%
# Epoch 25/30 - Train Loss: 0.2643, Train Acc: 93.06%, Val Loss: 0.5961, Val Acc: 86.43%
# Epoch 26/30 - Train Loss: 0.1154, Train Acc: 95.06%, Val Loss: 0.4855, Val Acc: 90.26%
# Epoch 27/30 - Train Loss: 0.1095, Train Acc: 95.35%, Val Loss: 0.4011, Val Acc: 90.87%
# Epoch 28/30 - Train Loss: 0.1016, Train Acc: 95.78%, Val Loss: 0.4312, Val Acc: 90.97%
# Epoch 29/30 - Train Loss: 0.1009, Train Acc: 95.66%, Val Loss: 0.5679, Val Acc: 90.40%
# Epoch 30/30 - Train Loss: 0.0992, Train Acc: 95.59%, Val Loss: 0.6137, Val Acc: 88.60%

# %%
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        mask = torch.ones(batch_X.size(0), batch_X.size(1)).to(device)
        outputs = model(batch_X, mask, None, None)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(batch_y.cpu().numpy())

test_acc = 100.0 * np.mean(np.array(all_preds) == np.array(all_labels))
print(f"Test Accuracy: {test_acc:.2f}%")

cm = confusion_matrix(all_labels, all_preds)
f1 = f1_score(all_labels, all_preds, average='weighted')
print("Confusion Matrix:")
print(cm)
print(f"F1 Score: {f1:.4f}")

# 혼동 행렬 시각화
import seaborn as sns
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=[f"Pred {i}" for i in range(config.num_class)],
            yticklabels=[f"True {i}" for i in range(config.num_class)])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Test Accuracy: 88.60%
# Confusion Matrix:
# [[466   4  26   0   0   0]
#  [  1 437  32   1   0   0]
#  [  0  20 400   0   0   0]
#  [  1   1   0 266 200  23]
#  [  0   0   0  27 505   0]
#  [  0   0   0   0   0 537]]
# F1 Score: 0.8810

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.fft
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, confusion_matrix
import math

# Device 설정
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print("Using device:", device)

# --- DataEmbedding ---
class DataEmbedding(nn.Module):
    def __init__(self, c_in, d_model, embed_type='fixed', freq='h', dropout=0.1):
        super(DataEmbedding, self).__init__()
        self.value_embedding = nn.Linear(c_in, d_model)
        self.dropout = nn.Dropout(dropout)
    def forward(self, x, x_mark):
        x = self.value_embedding(x)
        return self.dropout(x)

# --- Inception_Block_V2 (Improved Version) ---
class Inception_Block_V2(nn.Module):
    def __init__(self, in_channels, out_channels, num_kernels=3):
        super(Inception_Block_V2, self).__init__()
        kernel_sizes = [3, 5, 7][:num_kernels]
        self.conv_branches = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=(1, k), padding=(0, k // 2)),
                nn.BatchNorm2d(out_channels),
                nn.GELU()
            ) for k in kernel_sizes
        ])
        self.fusion = nn.Conv2d(out_channels, out_channels, kernel_size=1)

    def forward(self, x):
        outputs = [branch(x) for branch in self.conv_branches]
        out = sum(outputs) / len(outputs)  # average instead of sum
        return self.fusion(out)

# --- FFT_for_Period ---
def FFT_for_Period(x, k=2):
    xf = torch.fft.rfft(x, dim=1)
    frequency_list = abs(xf).mean(0).mean(-1)
    frequency_list[0] = 0
    _, top_list = torch.topk(frequency_list, k)
    top_list = top_list.detach().cpu().numpy()
    period = x.shape[1] // top_list
    return period, abs(xf).mean(-1)[:, top_list]

# --- TimesBlock (Improved) ---
class TimesBlock(nn.Module):
    def __init__(self, configs):
        super(TimesBlock, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.k = configs.top_k
        self.dropout = nn.Dropout(configs.dropout)
        self.layernorm = nn.LayerNorm(configs.d_model)
        self.conv = nn.Sequential(
            Inception_Block_V2(configs.d_model, configs.d_ff, num_kernels=configs.num_kernels),
            nn.Dropout(configs.dropout),
            Inception_Block_V2(configs.d_ff, configs.d_model, num_kernels=configs.num_kernels),
            nn.Dropout(configs.dropout)
        )

    def forward(self, x):
        B, T, N = x.size()
        period_list, period_weight = FFT_for_Period(x, self.k)
        res = []
        for i in range(self.k):
            period = period_list[i]
            length = ((self.seq_len + self.pred_len + period - 1) // period) * period
            padding = torch.zeros([B, length - (self.seq_len + self.pred_len), N]).to(x.device)
            out = torch.cat([x, padding], dim=1)
            out = out.reshape(B, length // period, period, N).permute(0, 3, 1, 2).contiguous()
            out = self.conv(out)
            out = out.permute(0, 2, 3, 1).reshape(B, -1, N)
            res.append(out[:, :(self.seq_len + self.pred_len), :])
        res = torch.stack(res, dim=-1)
        period_weight = F.softmax(period_weight, dim=1)
        period_weight = period_weight.unsqueeze(1).unsqueeze(1).repeat(1, T, N, 1)
        res = torch.sum(res * period_weight, -1)
        return self.layernorm(x + self.dropout(res))

# --- TimesNet Model (Improved) ---
class Model(nn.Module):
    def __init__(self, configs):
        super(Model, self).__init__()
        self.configs = configs
        self.task_name = configs.task_name
        self.seq_len = configs.seq_len
        self.label_len = configs.label_len
        self.pred_len = configs.pred_len
        self.model = nn.ModuleList([TimesBlock(configs) for _ in range(configs.e_layers)])
        self.enc_embedding = DataEmbedding(configs.enc_in, configs.d_model, configs.embed, configs.freq, configs.dropout)
        self.layer = configs.e_layers
        self.layer_norm = nn.LayerNorm(configs.d_model)
        if self.task_name == 'classification':
            self.act = F.gelu
            self.dropout = nn.Dropout(configs.dropout)
            self.projection = nn.Sequential(
                nn.LayerNorm(configs.d_model * configs.seq_len),
                nn.Linear(configs.d_model * configs.seq_len, configs.d_model),
                nn.GELU(),
                nn.Dropout(configs.dropout),
                nn.Linear(configs.d_model, configs.num_class)
            )

    def classification(self, x_enc, x_mark_enc):
        enc_out = self.enc_embedding(x_enc, None)
        for i in range(self.layer):
            enc_out = self.layer_norm(self.model[i](enc_out))
        output = self.act(enc_out)
        output = self.dropout(output)
        output = output * x_mark_enc.unsqueeze(-1)
        output = output.reshape(output.shape[0], -1)
        output = self.projection(output)
        return output

    def forward(self, x_enc, x_mark_enc, x_dec=None, x_mark_dec=None, mask=None):
        if self.task_name == 'classification':
            return self.classification(x_enc, x_mark_enc)
        return None

# --- Config 클래스 ---
class Config:
    def __init__(self):
        self.task_name = 'classification'
        self.seq_len = 128
        self.label_len = 128
        self.pred_len = 0
        self.e_layers = 3
        self.enc_in = 9
        self.d_model = 64
        self.embed = 'fixed'
        self.freq = 'h'
        self.dropout = 0.1
        self.d_ff = 256
        self.num_kernels = 3
        self.top_k = 2
        self.num_class = 12
        self.c_out = 1

print("Improved TimesNet model loaded.")
# Out:
# Using device: mps
# Improved TimesNet model loaded.

# %%
from torch.utils.data import TensorDataset, DataLoader

# 이미 준비된 데이터를 사용 (trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot)
# 예시 출력 (이 변수들은 이미 메모리에 존재한다고 가정)
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)

# 레이블을 (N,) 형태로 변환
trainy = np.squeeze(trainy)
testy  = np.squeeze(testy)

# 텐서로 변환
X_train_tensor = torch.tensor(trainX, dtype=torch.float32)
X_test_tensor  = torch.tensor(testX, dtype=torch.float32)
y_train_tensor = torch.tensor(trainy, dtype=torch.long)
y_test_tensor  = torch.tensor(testy, dtype=torch.long)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset  = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 모델 인스턴스 생성
config = Config()
model = Model(config).to(device)
print(model)

# 학습 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 30

print("Training start...")
for epoch in range(num_epochs):
    # 학습 단계
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        # 마스크: 모두 1 (padding 없음 가정)
        mask = torch.ones(batch_X.size(0), batch_X.size(1)).to(device)
        outputs = model(batch_X, mask, None, None)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * batch_X.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch_y).sum().item()
        total += batch_y.size(0)
    epoch_loss = running_loss / total
    epoch_acc = 100.0 * correct / total

    # 검증 단계 (test_loader 사용)
    model.eval()
    running_val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for val_X, val_y in test_loader:
            val_X, val_y = val_X.to(device), val_y.to(device)
            mask_val = torch.ones(val_X.size(0), val_X.size(1)).to(device)
            outputs_val = model(val_X, mask_val, None, None)
            loss_val = criterion(outputs_val, val_y)
            running_val_loss += loss_val.item() * val_X.size(0)
            _, predicted_val = torch.max(outputs_val, 1)
            correct_val += (predicted_val == val_y).sum().item()
            total_val += val_y.size(0)
    val_loss = running_val_loss / total_val
    val_acc = 100.0 * correct_val / total_val

    print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.2f}%, " +
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")
# Out:
# X train shape:  (7352, 128, 9)
# Y train shape:  (7352, 1)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 9)
# Y test shape:  (2947, 1)
# Y test One hot shape:  (2947, 6)
# Model(
#   (model): ModuleList(
#     (0-2): 3 x TimesBlock(
#       (dropout): Dropout(p=0.1, inplace=False)
#       (layernorm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (conv): Sequential(
#         (0): Inception_Block_V2(
#           (conv_branches): ModuleList(
#             (0): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (1): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (2): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3))
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#           )
#           (fusion): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Dropout(p=0.1, inplace=False)
#         (2): Inception_Block_V2(
#           (conv_branches): ModuleList(
#             (0): Sequential(
#               (0): Conv2d(256, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (1): Sequential(
#               (0): Conv2d(256, 64, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (2): Sequential(
#               (0): Conv2d(256, 64, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3))
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#           )
#           (fusion): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (enc_embedding): DataEmbedding(
#     (value_embedding): Linear(in_features=9, out_features=64, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (projection): Sequential(
#     (0): LayerNorm((8192,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=8192, out_features=64, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Linear(in_features=64, out_features=12, bias=True)
#   )
# )
# Training start...
# Epoch 1/30 - Train Loss: 0.3749, Train Acc: 85.81%, Val Loss: 0.3286, Val Acc: 90.77%
# Epoch 2/30 - Train Loss: 0.1612, Train Acc: 93.40%, Val Loss: 0.4383, Val Acc: 90.40%
# Epoch 3/30 - Train Loss: 0.1571, Train Acc: 93.50%, Val Loss: 0.4397, Val Acc: 91.18%
# Epoch 4/30 - Train Loss: 0.1407, Train Acc: 94.45%, Val Loss: 0.5101, Val Acc: 92.06%
# Epoch 5/30 - Train Loss: 0.1237, Train Acc: 94.63%, Val Loss: 0.4669, Val Acc: 92.43%
# Epoch 6/30 - Train Loss: 0.1578, Train Acc: 94.06%, Val Loss: 0.4381, Val Acc: 91.86%
# Epoch 7/30 - Train Loss: 0.1212, Train Acc: 94.87%, Val Loss: 0.4098, Val Acc: 92.57%
# Epoch 8/30 - Train Loss: 0.1264, Train Acc: 94.79%, Val Loss: 0.4409, Val Acc: 92.16%
# Epoch 9/30 - Train Loss: 0.1384, Train Acc: 94.76%, Val Loss: 0.4358, Val Acc: 91.62%
# Epoch 10/30 - Train Loss: 0.1336, Train Acc: 94.53%, Val Loss: 0.4937, Val Acc: 91.08%
# Epoch 11/30 - Train Loss: 0.1135, Train Acc: 95.12%, Val Loss: 0.4644, Val Acc: 91.99%
# Epoch 12/30 - Train Loss: 0.1191, Train Acc: 94.78%, Val Loss: 0.4024, Val Acc: 92.53%
# Epoch 13/30 - Train Loss: 0.1186, Train Acc: 94.95%, Val Loss: 0.4509, Val Acc: 93.01%
# Epoch 14/30 - Train Loss: 0.1054, Train Acc: 95.38%, Val Loss: 0.4158, Val Acc: 92.87%
# Epoch 15/30 - Train Loss: 0.1058, Train Acc: 95.47%, Val Loss: 0.4475, Val Acc: 92.47%
# Epoch 16/30 - Train Loss: 0.1157, Train Acc: 95.17%, Val Loss: 0.4702, Val Acc: 91.92%
# Epoch 17/30 - Train Loss: 0.1218, Train Acc: 94.87%, Val Loss: 0.5775, Val Acc: 91.25%
# Epoch 18/30 - Train Loss: 0.1089, Train Acc: 95.32%, Val Loss: 0.5065, Val Acc: 91.92%
# Epoch 19/30 - Train Loss: 0.1105, Train Acc: 95.18%, Val Loss: 0.5363, Val Acc: 93.21%
# Epoch 20/30 - Train Loss: 0.0997, Train Acc: 95.67%, Val Loss: 0.4002, Val Acc: 91.99%
# Epoch 21/30 - Train Loss: 0.1036, Train Acc: 95.62%, Val Loss: 0.8623, Val Acc: 91.01%
# Epoch 22/30 - Train Loss: 0.1067, Train Acc: 95.33%, Val Loss: 0.5904, Val Acc: 90.50%
# Epoch 23/30 - Train Loss: 0.1423, Train Acc: 94.34%, Val Loss: 0.4108, Val Acc: 92.53%
# Epoch 24/30 - Train Loss: 0.1112, Train Acc: 94.99%, Val Loss: 0.4198, Val Acc: 91.99%
# Epoch 25/30 - Train Loss: 0.1056, Train Acc: 95.48%, Val Loss: 0.4845, Val Acc: 92.94%
# Epoch 26/30 - Train Loss: 0.0988, Train Acc: 95.46%, Val Loss: 0.7576, Val Acc: 88.56%
# Epoch 27/30 - Train Loss: 0.1180, Train Acc: 95.05%, Val Loss: 0.4111, Val Acc: 91.45%
# Epoch 28/30 - Train Loss: 0.1015, Train Acc: 95.72%, Val Loss: 0.4272, Val Acc: 91.86%
# Epoch 29/30 - Train Loss: 0.1035, Train Acc: 95.50%, Val Loss: 0.4500, Val Acc: 91.11%
# Epoch 30/30 - Train Loss: 0.1059, Train Acc: 95.55%, Val Loss: 0.4433, Val Acc: 91.41%

# %%
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        mask = torch.ones(batch_X.size(0), batch_X.size(1)).to(device)
        outputs = model(batch_X, mask, None, None)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(batch_y.cpu().numpy())

test_acc = 100.0 * np.mean(np.array(all_preds) == np.array(all_labels))
print(f"Test Accuracy: {test_acc:.2f}%")

cm = confusion_matrix(all_labels, all_preds)
f1 = f1_score(all_labels, all_preds, average='weighted')
print("Confusion Matrix:")
print(cm)
print(f"F1 Score: {f1:.4f}")

# 혼동 행렬 시각화
import seaborn as sns
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=[f"Pred {i}" for i in range(config.num_class)],
            yticklabels=[f"True {i}" for i in range(config.num_class)])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Test Accuracy: 91.41%
# Confusion Matrix:
# [[483   0  13   0   0   0]
#  [ 11 447  13   0   0   0]
#  [ 12   7 400   0   0   1]
#  [  0  15   0 405  62   9]
#  [  0   0   0 110 422   0]
#  [  0   0   0   0   0 537]]
# F1 Score: 0.9137

# %%
from torch.utils.data import TensorDataset, DataLoader
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# 데이터 로딩 및 전처리
trainy = np.squeeze(trainy)
testy  = np.squeeze(testy)

X_train_tensor = torch.tensor(trainX, dtype=torch.float32)
X_test_tensor  = torch.tensor(testX, dtype=torch.float32)
y_train_tensor = torch.tensor(trainy, dtype=torch.long)
y_test_tensor  = torch.tensor(testy, dtype=torch.long)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset  = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 모델 초기화
config = Config()
config.dropout = 0.2  # Dropout 증가
model = Model(config).to(device)
print(model)

# 학습 설정
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)
num_epochs = 30

best_val_acc = 0.0
print("Training start...")
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        mask = torch.ones(batch_X.size(0), batch_X.size(1)).to(device)
        outputs = model(batch_X, mask, None, None)
        loss = criterion(outputs, batch_y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        running_loss += loss.item() * batch_X.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch_y).sum().item()
        total += batch_y.size(0)

    scheduler.step()

    epoch_loss = running_loss / total
    epoch_acc = 100.0 * correct / total

    # 검증 단계
    model.eval()
    running_val_loss = 0.0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for val_X, val_y in test_loader:
            val_X, val_y = val_X.to(device), val_y.to(device)
            mask_val = torch.ones(val_X.size(0), val_X.size(1)).to(device)
            outputs_val = model(val_X, mask_val, None, None)
            loss_val = criterion(outputs_val, val_y)
            running_val_loss += loss_val.item() * val_X.size(0)
            _, predicted_val = torch.max(outputs_val, 1)
            correct_val += (predicted_val == val_y).sum().item()
            total_val += val_y.size(0)

    val_loss = running_val_loss / total_val
    val_acc = 100.0 * correct_val / total_val

    # 체크포인트 저장
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_timesnet.pth")
        print("✅ Best model updated!")

    print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.2f}%, " +
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")
# Out:
# Model(
#   (model): ModuleList(
#     (0-2): 3 x TimesBlock(
#       (dropout): Dropout(p=0.2, inplace=False)
#       (layernorm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (conv): Sequential(
#         (0): Inception_Block_V2(
#           (conv_branches): ModuleList(
#             (0): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (1): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (2): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3))
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#           )
#           (fusion): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Dropout(p=0.2, inplace=False)
#         (2): Inception_Block_V2(
#           (conv_branches): ModuleList(
#             (0): Sequential(
#               (0): Conv2d(256, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (1): Sequential(
#               (0): Conv2d(256, 64, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (2): Sequential(
#               (0): Conv2d(256, 64, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3))
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#           )
#           (fusion): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (enc_embedding): DataEmbedding(
#     (value_embedding): Linear(in_features=9, out_features=64, bias=True)
#     (dropout): Dropout(p=0.2, inplace=False)
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (projection): Sequential(
#     (0): LayerNorm((8192,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=8192, out_features=64, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=64, out_features=12, bias=True)
#   )
# )
# Training start...
# ✅ Best model updated!
# Epoch 1/30 - Train Loss: 0.9007, Train Acc: 85.72%, Val Loss: 0.9254, Val Acc: 90.09%
# ✅ Best model updated!
# Epoch 2/30 - Train Loss: 0.7273, Train Acc: 93.01%, Val Loss: 0.8405, Val Acc: 91.18%
# ✅ Best model updated!
# Epoch 3/30 - Train Loss: 0.6914, Train Acc: 94.50%, Val Loss: 0.8304, Val Acc: 91.52%
# ✅ Best model updated!
# Epoch 4/30 - Train Loss: 0.6805, Train Acc: 94.97%, Val Loss: 0.7513, Val Acc: 92.16%
# Epoch 5/30 - Train Loss: 0.6661, Train Acc: 94.91%, Val Loss: 0.7938, Val Acc: 91.86%
# ✅ Best model updated!
# Epoch 6/30 - Train Loss: 0.6593, Train Acc: 94.97%, Val Loss: 0.7555, Val Acc: 92.33%
# ✅ Best model updated!
# Epoch 7/30 - Train Loss: 0.6540, Train Acc: 95.18%, Val Loss: 0.7568, Val Acc: 92.37%
# Epoch 8/30 - Train Loss: 0.6515, Train Acc: 95.08%, Val Loss: 0.7562, Val Acc: 91.48%
# ✅ Best model updated!
# Epoch 9/30 - Train Loss: 0.6498, Train Acc: 95.31%, Val Loss: 0.8163, Val Acc: 92.74%
# Epoch 10/30 - Train Loss: 0.6503, Train Acc: 94.97%, Val Loss: 0.7325, Val Acc: 91.69%
# Epoch 11/30 - Train Loss: 0.6395, Train Acc: 95.24%, Val Loss: 0.7454, Val Acc: 92.64%
# ✅ Best model updated!
# Epoch 12/30 - Train Loss: 0.6386, Train Acc: 95.39%, Val Loss: 0.7796, Val Acc: 92.98%
# Epoch 13/30 - Train Loss: 0.6397, Train Acc: 95.10%, Val Loss: 0.7828, Val Acc: 91.86%
# ✅ Best model updated!
# Epoch 14/30 - Train Loss: 0.6345, Train Acc: 95.33%, Val Loss: 0.7642, Val Acc: 93.32%
# Epoch 15/30 - Train Loss: 0.6341, Train Acc: 95.61%, Val Loss: 0.7740, Val Acc: 92.70%
# Epoch 16/30 - Train Loss: 0.6359, Train Acc: 95.54%, Val Loss: 0.7766, Val Acc: 92.13%
# ✅ Best model updated!
# Epoch 17/30 - Train Loss: 0.6326, Train Acc: 95.28%, Val Loss: 0.7562, Val Acc: 93.35%
# Epoch 18/30 - Train Loss: 0.6313, Train Acc: 95.55%, Val Loss: 0.7682, Val Acc: 92.84%
# Epoch 19/30 - Train Loss: 0.6303, Train Acc: 95.97%, Val Loss: 0.7750, Val Acc: 91.69%
# Epoch 20/30 - Train Loss: 0.6314, Train Acc: 95.93%, Val Loss: 0.7744, Val Acc: 93.04%
# Epoch 21/30 - Train Loss: 0.6218, Train Acc: 96.34%, Val Loss: 0.7533, Val Acc: 92.50%
# ✅ Best model updated!
# Epoch 22/30 - Train Loss: 0.6214, Train Acc: 96.10%, Val Loss: 0.7458, Val Acc: 94.06%
# ✅ Best model updated!
# Epoch 23/30 - Train Loss: 0.6196, Train Acc: 96.42%, Val Loss: 0.7417, Val Acc: 94.33%
# Epoch 24/30 - Train Loss: 0.6160, Train Acc: 96.79%, Val Loss: 0.7502, Val Acc: 93.45%
# Epoch 25/30 - Train Loss: 0.6143, Train Acc: 96.35%, Val Loss: 0.7572, Val Acc: 92.94%
# Epoch 26/30 - Train Loss: 0.6175, Train Acc: 96.44%, Val Loss: 0.7448, Val Acc: 93.99%
# Epoch 27/30 - Train Loss: 0.6140, Train Acc: 96.71%, Val Loss: 0.7492, Val Acc: 93.45%
# Epoch 28/30 - Train Loss: 0.6159, Train Acc: 96.63%, Val Loss: 0.7647, Val Acc: 92.98%
# Epoch 29/30 - Train Loss: 0.6133, Train Acc: 96.65%, Val Loss: 0.7536, Val Acc: 93.45%
# Epoch 30/30 - Train Loss: 0.6102, Train Acc: 97.02%, Val Loss: 0.7527, Val Acc: 92.43%

# %%
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        mask = torch.ones(batch_X.size(0), batch_X.size(1)).to(device)
        outputs = model(batch_X, mask, None, None)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(batch_y.cpu().numpy())

test_acc = 100.0 * np.mean(np.array(all_preds) == np.array(all_labels))
print(f"Test Accuracy: {test_acc:.2f}%")

cm = confusion_matrix(all_labels, all_preds)
f1 = f1_score(all_labels, all_preds, average='weighted')
print("Confusion Matrix:")
print(cm)
print(f"F1 Score: {f1:.4f}")

# 혼동 행렬 시각화
import seaborn as sns
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=[f"Pred {i}" for i in range(config.num_class)],
            yticklabels=[f"True {i}" for i in range(config.num_class)])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Test Accuracy: 92.43%
# Confusion Matrix:
# [[479   0  17   0   0   0]
#  [  0 446  25   0   0   0]
#  [  0   0 420   0   0   0]
#  [  0   3   0 379  86  23]
#  [  0   0   1  68 463   0]
#  [  0   0   0   0   0 537]]
# F1 Score: 0.9236

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.fft
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, confusion_matrix
import math

# Device 설정
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print("Using device:", device)

# --- Positional Encoding ---
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.pe = pe.unsqueeze(0)

    def forward(self, x):
        return x + self.pe[:, :x.size(1)].to(x.device)

# --- DataEmbedding (with Positional Encoding) ---
class DataEmbedding(nn.Module):
    def __init__(self, c_in, d_model, embed_type='fixed', freq='h', dropout=0.1):
        super(DataEmbedding, self).__init__()
        self.value_embedding = nn.Linear(c_in, d_model)
        self.position_encoding = PositionalEncoding(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, x_mark):
        x = self.value_embedding(x)
        x = self.position_encoding(x)
        return self.dropout(x)

# --- Inception_Block_V2 (Fixed Fusion Channels) ---
class Inception_Block_V2(nn.Module):
    def __init__(self, in_channels, out_channels, num_kernels=3):
        super(Inception_Block_V2, self).__init__()
        kernel_sizes = [3, 5, 7][:num_kernels]
        self.num_kernels = len(kernel_sizes)
        self.conv_branches = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=(1, k), padding=(0, k // 2)),
                nn.BatchNorm2d(out_channels),
                nn.GELU()
            ) for k in kernel_sizes
        ])
        self.fusion = nn.Conv2d(out_channels * self.num_kernels, out_channels, kernel_size=1)

    def forward(self, x):
        outputs = [branch(x) for branch in self.conv_branches]
        out = torch.cat(outputs, dim=1)
        out = self.fusion(out)
        return out

# --- FFT_for_Period ---
def FFT_for_Period(x, k=2):
    xf = torch.fft.rfft(x, dim=1)
    frequency_list = abs(xf).mean(0).mean(-1)
    frequency_list[0] = 0
    _, top_list = torch.topk(frequency_list, k)
    top_list = top_list.detach().cpu().numpy()
    period = x.shape[1] // top_list
    return period, abs(xf).mean(-1)[:, top_list]

# --- TimesBlock ---
class TimesBlock(nn.Module):
    def __init__(self, configs):
        super(TimesBlock, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.k = configs.top_k
        self.dropout = nn.Dropout(configs.dropout)
        self.layernorm = nn.LayerNorm(configs.d_model)
        self.conv = nn.Sequential(
            Inception_Block_V2(configs.d_model, configs.d_ff, num_kernels=configs.num_kernels),
            nn.Dropout(configs.dropout),
            Inception_Block_V2(configs.d_ff, configs.d_model, num_kernels=configs.num_kernels),
            nn.Dropout(configs.dropout)
        )

    def forward(self, x):
        B, T, N = x.size()
        period_list, period_weight = FFT_for_Period(x, self.k)
        res = []
        for i in range(self.k):
            period = period_list[i]
            length = ((self.seq_len + self.pred_len + period - 1) // period) * period
            padding = torch.zeros([B, length - (self.seq_len + self.pred_len), N]).to(x.device)
            out = torch.cat([x, padding], dim=1)
            out = out.reshape(B, length // period, period, N).permute(0, 3, 1, 2).contiguous()
            out = self.conv(out)
            out = out.permute(0, 2, 3, 1).reshape(B, -1, N)
            res.append(out[:, :(self.seq_len + self.pred_len), :])
        res = torch.stack(res, dim=-1)
        period_weight = F.softmax(period_weight, dim=1)
        period_weight = period_weight.unsqueeze(1).unsqueeze(1).repeat(1, T, N, 1)
        res = torch.sum(res * period_weight, -1)
        return self.layernorm(x + self.dropout(res))

# --- TimesNet Model ---
class Model(nn.Module):
    def __init__(self, configs):
        super(Model, self).__init__()
        self.configs = configs
        self.task_name = configs.task_name
        self.seq_len = configs.seq_len
        self.label_len = configs.label_len
        self.pred_len = configs.pred_len
        self.model = nn.ModuleList([TimesBlock(configs) for _ in range(configs.e_layers)])
        self.enc_embedding = DataEmbedding(configs.enc_in, configs.d_model, configs.embed, configs.freq, configs.dropout)
        self.layer = configs.e_layers
        self.layer_norm = nn.LayerNorm(configs.d_model)
        if self.task_name == 'classification':
            self.act = F.gelu
            self.dropout = nn.Dropout(configs.dropout)
            self.projection = nn.Sequential(
                nn.LayerNorm(configs.d_model * configs.seq_len),
                nn.Linear(configs.d_model * configs.seq_len, configs.d_model),
                nn.GELU(),
                nn.Dropout(configs.dropout),
                nn.Linear(configs.d_model, configs.num_class)
            )

    def classification(self, x_enc, x_mark_enc):
        enc_out = self.enc_embedding(x_enc, None)
        for i in range(self.layer):
            enc_out = self.layer_norm(self.model[i](enc_out))
        output = self.act(enc_out)
        output = self.dropout(output)
        output = output * x_mark_enc.unsqueeze(-1)
        output = output.reshape(output.shape[0], -1)
        output = self.projection(output)
        return output

    def forward(self, x_enc, x_mark_enc, x_dec=None, x_mark_dec=None, mask=None):
        if self.task_name == 'classification':
            return self.classification(x_enc, x_mark_enc)
        return None

# --- Config 클래스 ---
class Config:
    def __init__(self):
        self.task_name = 'classification'
        self.seq_len = 128
        self.label_len = 128
        self.pred_len = 0
        self.e_layers = 4
        self.enc_in = 9
        self.d_model = 128
        self.embed = 'fixed'
        self.freq = 'h'
        self.dropout = 0.2
        self.d_ff = 512
        self.num_kernels = 3
        self.top_k = 2
        self.num_class = 12
        self.c_out = 1

print("✅ Fixed and complete TimesNet model is ready.")
# Out:
# Using device: mps
# ✅ Fixed and complete TimesNet model is ready.

# %%
from torch.utils.data import TensorDataset, DataLoader

# 이미 준비된 데이터를 사용 (trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot)
# 예시 출력 (이 변수들은 이미 메모리에 존재한다고 가정)
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)

# 레이블을 (N,) 형태로 변환
trainy = np.squeeze(trainy)
testy  = np.squeeze(testy)

# 텐서로 변환
X_train_tensor = torch.tensor(trainX, dtype=torch.float32)
X_test_tensor  = torch.tensor(testX, dtype=torch.float32)
y_train_tensor = torch.tensor(trainy, dtype=torch.long)
y_test_tensor  = torch.tensor(testy, dtype=torch.long)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset  = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 모델 인스턴스 생성
config = Config()
model = Model(config).to(device)
print(model)

# 학습 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 30

print("Training start...")
for epoch in range(num_epochs):
    # 학습 단계
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        # 마스크: 모두 1 (padding 없음 가정)
        mask = torch.ones(batch_X.size(0), batch_X.size(1)).to(device)
        outputs = model(batch_X, mask, None, None)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * batch_X.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch_y).sum().item()
        total += batch_y.size(0)
    epoch_loss = running_loss / total
    epoch_acc = 100.0 * correct / total

    # 검증 단계 (test_loader 사용)
    model.eval()
    running_val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for val_X, val_y in test_loader:
            val_X, val_y = val_X.to(device), val_y.to(device)
            mask_val = torch.ones(val_X.size(0), val_X.size(1)).to(device)
            outputs_val = model(val_X, mask_val, None, None)
            loss_val = criterion(outputs_val, val_y)
            running_val_loss += loss_val.item() * val_X.size(0)
            _, predicted_val = torch.max(outputs_val, 1)
            correct_val += (predicted_val == val_y).sum().item()
            total_val += val_y.size(0)
    val_loss = running_val_loss / total_val
    val_acc = 100.0 * correct_val / total_val

    print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.2f}%, " +
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")
# Out:
# X train shape:  (7352, 128, 9)
# Y train shape:  (7352,)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 9)
# Y test shape:  (2947,)
# Y test One hot shape:  (2947, 6)
# Model(
#   (model): ModuleList(
#     (0-3): 4 x TimesBlock(
#       (dropout): Dropout(p=0.2, inplace=False)
#       (layernorm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (conv): Sequential(
#         (0): Inception_Block_V2(
#           (conv_branches): ModuleList(
#             (0): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (2): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3))
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#           )
#           (fusion): Conv2d(1536, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Dropout(p=0.2, inplace=False)
#         (2): Inception_Block_V2(
#           (conv_branches): ModuleList(
#             (0): Sequential(
#               (0): Conv2d(512, 128, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (1): Sequential(
#               (0): Conv2d(512, 128, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (2): Sequential(
#               (0): Conv2d(512, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#           )
#           (fusion): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (enc_embedding): DataEmbedding(
#     (value_embedding): Linear(in_features=9, out_features=128, bias=True)
#     (position_encoding): PositionalEncoding()
#     (dropout): Dropout(p=0.2, inplace=False)
#   )
#   (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (projection): Sequential(
#     (0): LayerNorm((16384,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=16384, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=128, out_features=12, bias=True)
#   )
# )
# Training start...
# Epoch 1/30 - Train Loss: 0.8219, Train Acc: 68.12%, Val Loss: 0.5774, Val Acc: 77.10%
# Epoch 2/30 - Train Loss: 0.4172, Train Acc: 83.94%, Val Loss: 0.3761, Val Acc: 87.38%
# Epoch 3/30 - Train Loss: 0.2741, Train Acc: 89.01%, Val Loss: 0.2477, Val Acc: 89.35%
# Epoch 4/30 - Train Loss: 0.2244, Train Acc: 91.53%, Val Loss: 0.4142, Val Acc: 89.18%
# Epoch 5/30 - Train Loss: 0.2330, Train Acc: 91.13%, Val Loss: 0.4052, Val Acc: 88.23%
# Epoch 6/30 - Train Loss: 0.1841, Train Acc: 92.36%, Val Loss: 0.4550, Val Acc: 89.28%
# Epoch 7/30 - Train Loss: 0.1711, Train Acc: 93.36%, Val Loss: 0.3784, Val Acc: 90.57%
# Epoch 8/30 - Train Loss: 0.1552, Train Acc: 93.66%, Val Loss: 0.3385, Val Acc: 91.28%
# Epoch 9/30 - Train Loss: 0.1440, Train Acc: 94.02%, Val Loss: 0.4400, Val Acc: 90.26%
# Epoch 10/30 - Train Loss: 0.1639, Train Acc: 93.35%, Val Loss: 0.3740, Val Acc: 88.97%
# Epoch 11/30 - Train Loss: 0.1770, Train Acc: 93.12%, Val Loss: 0.4325, Val Acc: 90.23%
# Epoch 12/30 - Train Loss: 0.1363, Train Acc: 94.53%, Val Loss: 0.3764, Val Acc: 90.23%
# Epoch 13/30 - Train Loss: 0.1415, Train Acc: 94.04%, Val Loss: 0.5046, Val Acc: 89.65%
# Epoch 14/30 - Train Loss: 0.1300, Train Acc: 94.41%, Val Loss: 0.4479, Val Acc: 90.63%
# Epoch 15/30 - Train Loss: 0.1334, Train Acc: 94.19%, Val Loss: 0.4277, Val Acc: 90.53%
# Epoch 16/30 - Train Loss: 0.1472, Train Acc: 93.82%, Val Loss: 0.3820, Val Acc: 88.56%
# Epoch 17/30 - Train Loss: 0.1873, Train Acc: 92.68%, Val Loss: 0.4250, Val Acc: 90.23%
# Epoch 18/30 - Train Loss: 0.1421, Train Acc: 94.03%, Val Loss: 0.3875, Val Acc: 91.65%
# Epoch 19/30 - Train Loss: 0.1302, Train Acc: 94.53%, Val Loss: 0.4348, Val Acc: 91.25%
# Epoch 20/30 - Train Loss: 0.1358, Train Acc: 94.29%, Val Loss: 0.3289, Val Acc: 90.97%
# Epoch 21/30 - Train Loss: 0.1445, Train Acc: 94.40%, Val Loss: 0.5285, Val Acc: 90.94%
# Epoch 22/30 - Train Loss: 0.1383, Train Acc: 94.11%, Val Loss: 0.4136, Val Acc: 90.70%
# Epoch 23/30 - Train Loss: 0.1286, Train Acc: 94.22%, Val Loss: 0.4108, Val Acc: 90.84%
# Epoch 24/30 - Train Loss: 0.1542, Train Acc: 93.66%, Val Loss: 0.6425, Val Acc: 89.89%
# Epoch 25/30 - Train Loss: 0.1591, Train Acc: 93.59%, Val Loss: 0.4641, Val Acc: 90.02%
# Epoch 26/30 - Train Loss: 0.1328, Train Acc: 94.34%, Val Loss: 0.3803, Val Acc: 92.43%
# Epoch 27/30 - Train Loss: 0.1222, Train Acc: 94.79%, Val Loss: 0.4300, Val Acc: 90.16%
# Epoch 28/30 - Train Loss: 0.1250, Train Acc: 94.65%, Val Loss: 0.3978, Val Acc: 89.18%
# Epoch 29/30 - Train Loss: 0.1542, Train Acc: 94.06%, Val Loss: 0.3393, Val Acc: 91.41%
# Epoch 30/30 - Train Loss: 0.1248, Train Acc: 94.82%, Val Loss: 0.3909, Val Acc: 91.04%

# %%
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        mask = torch.ones(batch_X.size(0), batch_X.size(1)).to(device)
        outputs = model(batch_X, mask, None, None)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(batch_y.cpu().numpy())

test_acc = 100.0 * np.mean(np.array(all_preds) == np.array(all_labels))
print(f"Test Accuracy: {test_acc:.2f}%")

cm = confusion_matrix(all_labels, all_preds)
f1 = f1_score(all_labels, all_preds, average='weighted')
print("Confusion Matrix:")
print(cm)
print(f"F1 Score: {f1:.4f}")

# 혼동 행렬 시각화
import seaborn as sns
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=[f"Pred {i}" for i in range(config.num_class)],
            yticklabels=[f"True {i}" for i in range(config.num_class)])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Test Accuracy: 91.04%
# Confusion Matrix:
# [[478   0  18   0   0   0]
#  [  5 446  20   0   0   0]
#  [  3   4 413   0   0   0]
#  [  0   3   1 389  97   1]
#  [  0   0   0  93 439   0]
#  [  0  19   0   0   0 518]]
# F1 Score: 0.9104

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.fft
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, confusion_matrix
import math

# Device 설정
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print("Using device:", device)

# --- Modified Positional Encoding with learnable option ---
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000, learnable=False):
        super().__init__()
        if not learnable:
            pe = torch.zeros(max_len, d_model)
            position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
            div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
            pe[:, 0::2] = torch.sin(position * div_term)
            pe[:, 1::2] = torch.cos(position * div_term)
            self.pe = pe.unsqueeze(0)  # shape [1, max_len, d_model]
        else:
            self.pe = nn.Parameter(torch.randn(1, max_len, d_model))
        self.learnable = learnable

    def forward(self, x):
        return x + self.pe[:, :x.size(1)].to(x.device)

# --- Modified DataEmbedding (with learnable positional encoding option) ---
class DataEmbedding(nn.Module):
    def __init__(self, c_in, d_model, embed_type='fixed', freq='h', dropout=0.1):
        super(DataEmbedding, self).__init__()
        self.value_embedding = nn.Linear(c_in, d_model)
        # embed_type 'learnable'이면 학습 가능한 positional encoding 사용
        learnable = True if embed_type == 'learnable' else False
        self.position_encoding = PositionalEncoding(d_model, learnable=learnable)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, x_mark):
        x = self.value_embedding(x)
        x = self.position_encoding(x)
        return self.dropout(x)

# --- Modified Inception_Block_V2 with Squeeze-and-Excitation (SE) module ---
class Inception_Block_V2(nn.Module):
    def __init__(self, in_channels, out_channels, num_kernels=3):
        super(Inception_Block_V2, self).__init__()
        kernel_sizes = [3, 5, 7][:num_kernels]
        self.num_kernels = len(kernel_sizes)
        self.conv_branches = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=(1, k), padding=(0, k // 2)),
                nn.BatchNorm2d(out_channels),
                nn.GELU()
            ) for k in kernel_sizes
        ])
        # Squeeze-and-Excitation module for channel attention
        self.se = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(out_channels * self.num_kernels, (out_channels * self.num_kernels) // 16, kernel_size=1),
            nn.ReLU(),
            nn.Conv2d((out_channels * self.num_kernels) // 16, out_channels * self.num_kernels, kernel_size=1),
            nn.Sigmoid()
        )
        self.fusion = nn.Conv2d(out_channels * self.num_kernels, out_channels, kernel_size=1)

    def forward(self, x):
        outputs = [branch(x) for branch in self.conv_branches]
        out = torch.cat(outputs, dim=1)
        # Apply SE attention
        se_weight = self.se(out)
        out = out * se_weight
        out = self.fusion(out)
        return out

# --- Modified FFT_for_Period ---
def FFT_for_Period(x, k=2):
    xf = torch.fft.rfft(x, dim=1)
    frequency_list = abs(xf).mean(0).mean(-1)
    frequency_list[0] = 0
    _, top_list = torch.topk(frequency_list, k)
    top_list = top_list.detach().cpu().numpy()
    # 각 상위 주파수에 대해 주기를 계산
    periods = x.shape[1] // top_list
    period_weights = abs(xf).mean(-1)[:, top_list]  # shape: (B, k)
    return periods, period_weights

# --- Modified TimesBlock with learnable gating for period fusion ---
class TimesBlock(nn.Module):
    def __init__(self, configs):
        super(TimesBlock, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.k = configs.top_k
        self.dropout = nn.Dropout(configs.dropout)
        self.layernorm = nn.LayerNorm(configs.d_model)
        self.conv = nn.Sequential(
            Inception_Block_V2(configs.d_model, configs.d_ff, num_kernels=configs.num_kernels),
            nn.Dropout(configs.dropout),
            Inception_Block_V2(configs.d_ff, configs.d_model, num_kernels=configs.num_kernels),
            nn.Dropout(configs.dropout)
        )
        # Learnable gating parameters for period fusion, shape (k,)
        self.gate = nn.Parameter(torch.zeros(self.k))

    def forward(self, x):
        B, T, N = x.size()
        period_list, period_weight = FFT_for_Period(x, self.k)  # period_list: array of k periods, period_weight: (B, k)
        res = []
        for i in range(self.k):
            period = period_list[i]
            length = ((self.seq_len + self.pred_len + period - 1) // period) * period
            padding = torch.zeros([B, length - (self.seq_len + self.pred_len), N]).to(x.device)
            out = torch.cat([x, padding], dim=1)
            out = out.reshape(B, length // period, period, N).permute(0, 3, 1, 2).contiguous()
            out = self.conv(out)
            out = out.permute(0, 2, 3, 1).reshape(B, -1, N)
            res.append(out[:, :(self.seq_len + self.pred_len), :])
        res = torch.stack(res, dim=-1)  # shape: (B, T, N, k)
        # Combine FFT-derived weights with learnable gating
        combined_weight = period_weight + self.gate.unsqueeze(0)  # shape: (B, k)
        combined_weight = F.softmax(combined_weight, dim=-1)
        combined_weight = combined_weight.unsqueeze(1).unsqueeze(1).repeat(1, T, N, 1)
        res = torch.sum(res * combined_weight, -1)
        return self.layernorm(x + self.dropout(res))

# --- Modified TimesNet Model with attention pooling for classification ---
class Model(nn.Module):
    def __init__(self, configs):
        super(Model, self).__init__()
        self.configs = configs
        self.task_name = configs.task_name
        self.seq_len = configs.seq_len
        self.label_len = configs.label_len
        self.pred_len = configs.pred_len
        self.model = nn.ModuleList([TimesBlock(configs) for _ in range(configs.e_layers)])
        self.enc_embedding = DataEmbedding(configs.enc_in, configs.d_model, configs.embed, configs.freq, configs.dropout)
        self.layer = configs.e_layers
        self.layer_norm = nn.LayerNorm(configs.d_model)
        if self.task_name == 'classification':
            self.act = F.gelu
            self.dropout = nn.Dropout(configs.dropout)
            # Attention pooling for time dimension
            self.attn_pool = nn.Sequential(
                nn.Linear(configs.d_model, configs.d_model),
                nn.Tanh(),
                nn.Linear(configs.d_model, 1)
            )
            self.projection = nn.Sequential(
                nn.LayerNorm(configs.d_model),
                nn.Linear(configs.d_model, configs.num_class)
            )

    def classification(self, x_enc, x_mark_enc):
        enc_out = self.enc_embedding(x_enc, None)
        for i in range(self.layer):
            enc_out = self.layer_norm(self.model[i](enc_out))
        output = self.act(enc_out)
        output = self.dropout(output)
        # Attention pooling over the time dimension
        attn_scores = self.attn_pool(output)  # shape: (B, T, 1)
        attn_weights = F.softmax(attn_scores, dim=1)
        pooled = torch.sum(output * attn_weights, dim=1)  # shape: (B, d_model)
        output = self.projection(pooled)
        return output

    def forward(self, x_enc, x_mark_enc, x_dec=None, x_mark_dec=None, mask=None):
        if self.task_name == 'classification':
            return self.classification(x_enc, x_mark_enc)
        return None

# --- Modified Config 클래스 with option for learnable positional encoding ---
class Config:
    def __init__(self):
        self.task_name = 'classification'
        self.seq_len = 128
        self.label_len = 128
        self.pred_len = 0
        self.e_layers = 4
        self.enc_in = 9
        self.d_model = 128
        self.embed = 'learnable'  # Use learnable positional encoding
        self.freq = 'h'
        self.dropout = 0.2
        self.d_ff = 512
        self.num_kernels = 3
        self.top_k = 2
        self.num_class = 12
        self.c_out = 1

print("✅ Modified TimesNet model with performance improvements is ready.")
# Out:
# Using device: mps
# ✅ Modified TimesNet model with performance improvements is ready.

# %%
from torch.utils.data import TensorDataset, DataLoader

# 이미 준비된 데이터를 사용 (trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot)
# 예시 출력 (이 변수들은 이미 메모리에 존재한다고 가정)
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)

# 레이블을 (N,) 형태로 변환
trainy = np.squeeze(trainy)
testy  = np.squeeze(testy)

# 텐서로 변환
X_train_tensor = torch.tensor(trainX, dtype=torch.float32)
X_test_tensor  = torch.tensor(testX, dtype=torch.float32)
y_train_tensor = torch.tensor(trainy, dtype=torch.long)
y_test_tensor  = torch.tensor(testy, dtype=torch.long)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset  = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 모델 인스턴스 생성
config = Config()
model = Model(config).to(device)
print(model)

# 학습 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 30

print("Training start...")
for epoch in range(num_epochs):
    # 학습 단계
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        # 마스크: 모두 1 (padding 없음 가정)
        mask = torch.ones(batch_X.size(0), batch_X.size(1)).to(device)
        outputs = model(batch_X, mask, None, None)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * batch_X.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch_y).sum().item()
        total += batch_y.size(0)
    epoch_loss = running_loss / total
    epoch_acc = 100.0 * correct / total

    # 검증 단계 (test_loader 사용)
    model.eval()
    running_val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for val_X, val_y in test_loader:
            val_X, val_y = val_X.to(device), val_y.to(device)
            mask_val = torch.ones(val_X.size(0), val_X.size(1)).to(device)
            outputs_val = model(val_X, mask_val, None, None)
            loss_val = criterion(outputs_val, val_y)
            running_val_loss += loss_val.item() * val_X.size(0)
            _, predicted_val = torch.max(outputs_val, 1)
            correct_val += (predicted_val == val_y).sum().item()
            total_val += val_y.size(0)
    val_loss = running_val_loss / total_val
    val_acc = 100.0 * correct_val / total_val

    print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.2f}%, " +
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")
# Out:
# X train shape:  (7352, 128, 9)
# Y train shape:  (7352, 1)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 9)
# Y test shape:  (2947, 1)
# Y test One hot shape:  (2947, 6)
# Model(
#   (model): ModuleList(
#     (0-3): 4 x TimesBlock(
#       (dropout): Dropout(p=0.2, inplace=False)
#       (layernorm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (conv): Sequential(
#         (0): Inception_Block_V2(
#           (conv_branches): ModuleList(
#             (0): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (1): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (2): Sequential(
#               (0): Conv2d(128, 512, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3))
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#           )
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1536, 96, kernel_size=(1, 1), stride=(1, 1))
#             (2): ReLU()
#             (3): Conv2d(96, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#           (fusion): Conv2d(1536, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Dropout(p=0.2, inplace=False)
#         (2): Inception_Block_V2(
#           (conv_branches): ModuleList(
#             (0): Sequential(
#               (0): Conv2d(512, 128, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (1): Sequential(
#               (0): Conv2d(512, 128, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#             (2): Sequential(
#               (0): Conv2d(512, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3))
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): GELU(approximate='none')
#             )
#           )
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(384, 24, kernel_size=(1, 1), stride=(1, 1))
#             (2): ReLU()
#             (3): Conv2d(24, 384, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#           (fusion): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (enc_embedding): DataEmbedding(
#     (value_embedding): Linear(in_features=9, out_features=128, bias=True)
#     (position_encoding): PositionalEncoding()
#     (dropout): Dropout(p=0.2, inplace=False)
#   )
#   (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (attn_pool): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (projection): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=12, bias=True)
#   )
# )
# Training start...
# Epoch 1/30 - Train Loss: 0.5539, Train Acc: 79.04%, Val Loss: 0.6633, Val Acc: 77.33%
# Epoch 2/30 - Train Loss: 0.2396, Train Acc: 90.89%, Val Loss: 0.6863, Val Acc: 77.94%
# Epoch 3/30 - Train Loss: 0.2131, Train Acc: 91.57%, Val Loss: 0.2578, Val Acc: 90.63%
# Epoch 4/30 - Train Loss: 0.1749, Train Acc: 93.06%, Val Loss: 0.2944, Val Acc: 90.63%
# Epoch 5/30 - Train Loss: 0.1521, Train Acc: 93.62%, Val Loss: 0.2802, Val Acc: 88.56%
# Epoch 6/30 - Train Loss: 0.1545, Train Acc: 93.59%, Val Loss: 0.2581, Val Acc: 90.80%
# Epoch 7/30 - Train Loss: 0.1434, Train Acc: 94.10%, Val Loss: 0.2976, Val Acc: 90.40%
# Epoch 8/30 - Train Loss: 0.1365, Train Acc: 94.27%, Val Loss: 0.2165, Val Acc: 91.79%
# Epoch 9/30 - Train Loss: 0.1497, Train Acc: 93.69%, Val Loss: 0.2782, Val Acc: 91.41%
# Epoch 10/30 - Train Loss: 0.1342, Train Acc: 94.48%, Val Loss: 0.2818, Val Acc: 91.21%
# Epoch 11/30 - Train Loss: 0.1235, Train Acc: 94.93%, Val Loss: 0.3273, Val Acc: 91.69%
# Epoch 12/30 - Train Loss: 0.1305, Train Acc: 94.30%, Val Loss: 0.3286, Val Acc: 90.30%
# Epoch 13/30 - Train Loss: 0.1304, Train Acc: 94.48%, Val Loss: 0.2429, Val Acc: 90.13%
# Epoch 14/30 - Train Loss: 0.1222, Train Acc: 94.89%, Val Loss: 0.2802, Val Acc: 90.80%
# Epoch 15/30 - Train Loss: 0.1211, Train Acc: 94.89%, Val Loss: 0.2835, Val Acc: 91.55%
# Epoch 16/30 - Train Loss: 0.1228, Train Acc: 94.93%, Val Loss: 0.2119, Val Acc: 92.47%
# Epoch 17/30 - Train Loss: 0.1154, Train Acc: 94.94%, Val Loss: 0.2185, Val Acc: 93.04%
# Epoch 18/30 - Train Loss: 0.1170, Train Acc: 94.95%, Val Loss: 0.3428, Val Acc: 91.21%
# Epoch 19/30 - Train Loss: 0.1211, Train Acc: 94.98%, Val Loss: 0.2399, Val Acc: 92.40%
# Epoch 20/30 - Train Loss: 0.1191, Train Acc: 94.89%, Val Loss: 0.2754, Val Acc: 91.99%
# Epoch 21/30 - Train Loss: 0.1110, Train Acc: 95.16%, Val Loss: 0.2929, Val Acc: 91.45%
# Epoch 22/30 - Train Loss: 0.1241, Train Acc: 94.75%, Val Loss: 0.2787, Val Acc: 91.11%
# Epoch 23/30 - Train Loss: 0.1130, Train Acc: 95.12%, Val Loss: 0.3462, Val Acc: 91.48%
# Epoch 24/30 - Train Loss: 0.1133, Train Acc: 95.31%, Val Loss: 0.3761, Val Acc: 90.67%
# Epoch 25/30 - Train Loss: 0.1152, Train Acc: 95.24%, Val Loss: 0.3815, Val Acc: 91.31%
# Epoch 26/30 - Train Loss: 0.1105, Train Acc: 95.31%, Val Loss: 0.2969, Val Acc: 91.45%
# Epoch 27/30 - Train Loss: 0.1077, Train Acc: 94.99%, Val Loss: 0.2711, Val Acc: 92.37%
# Epoch 28/30 - Train Loss: 0.1083, Train Acc: 95.53%, Val Loss: 0.5045, Val Acc: 89.11%
# Epoch 29/30 - Train Loss: 0.1108, Train Acc: 95.23%, Val Loss: 0.2873, Val Acc: 91.38%
# Epoch 30/30 - Train Loss: 0.0992, Train Acc: 95.42%, Val Loss: 0.3162, Val Acc: 91.48%

# %%
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        mask = torch.ones(batch_X.size(0), batch_X.size(1)).to(device)
        outputs = model(batch_X, mask, None, None)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(batch_y.cpu().numpy())

test_acc = 100.0 * np.mean(np.array(all_preds) == np.array(all_labels))
print(f"Test Accuracy: {test_acc:.2f}%")

cm = confusion_matrix(all_labels, all_preds)
f1 = f1_score(all_labels, all_preds, average='weighted')
print("Confusion Matrix:")
print(cm)
print(f"F1 Score: {f1:.4f}")

# 혼동 행렬 시각화
import seaborn as sns
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=[f"Pred {i}" for i in range(config.num_class)],
            yticklabels=[f"True {i}" for i in range(config.num_class)])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Test Accuracy: 91.48%
# Confusion Matrix:
# [[472   1  22   0   1   0]
#  [  2 441  28   0   0   0]
#  [  0   0 420   0   0   0]
#  [  0   2   0 365 120   4]
#  [  0   0   0  71 461   0]
#  [  0   0   0   0   0 537]]
# F1 Score: 0.9145
